# %%
from thesisv3.validation.tuners import *
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\.School\Thesisv3\.venv\Lib\site-packages\tslearn\bases\bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %%
results = compare_kernels(
    batcher_output_dir='Output/batcher_output',
    min_k=1,
    max_k=10,
    k_step=1
)
# Out:
# ...
# Testing kernel: WeisfeilerLehman
# ...
#
# Attempting to load data from GraphBatcher output directory: ./batcher_output
# Successfully loaded data from GraphBatcher: 39 files
# Previously calculated results for 9 k values
# Using cached results for k = 1
# Using cached results for k = 2
# Using cached results for k = 3
# Using cached results for k = 4
# Using cached results for k = 5
# Using cached results for k = 6
# Using cached results for k = 7
# Using cached results for k = 8
# Using cached results for k = 9
#
#
# ...
# Testing kernel: ShortestPath
# ...
#
# Attempting to load data from GraphBatcher output directory: ./batcher_output
# Successfully loaded data from GraphBatcher: 39 files
# Previously calculated results for 9 k values
# Using cached results for k = 1
# Using cached results for k = 2
# Using cached results for k = 3
# Using cached results for k = 4
# Using cached results for k = 5
# Using cached results for k = 6
# Using cached results for k = 7
# Using cached results for k = 8
# ...

# %%
kernel = gk.WeisfeilerLehman(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
tuner = KNNGraphTuner(
    graph_kernel=gk.WeisfeilerLehman(normalize=True),
    batcher_output_dir='Output/batcher_output_k5'
)
# Out:
# Attempting to load data from GraphBatcher output directory: ./batcher_output_k5
# File not found: ./tuner_output\tuner_results.pkl
# Successfully loaded data from GraphBatcher: 35 files
# Previously calculated results for 0 k values

# %%
tuner.calculate_and_graph()
# Out:
# Calculating graph statistics at k = 1
# Progress saved: 35 files processed, 1 k values calculated
# Calculating graph statistics at k = 2
# Progress saved: 35 files processed, 2 k values calculated
# Calculating graph statistics at k = 3
# Progress saved: 35 files processed, 3 k values calculated
# Calculating graph statistics at k = 4
# Progress saved: 35 files processed, 4 k values calculated
# Calculating graph statistics at k = 5
# Progress saved: 35 files processed, 5 k values calculated
# Calculating graph statistics at k = 6
# Progress saved: 35 files processed, 6 k values calculated
# Calculating graph statistics at k = 7
# Progress saved: 35 files processed, 7 k values calculated
# Calculating graph statistics at k = 8
# Progress saved: 35 files processed, 8 k values calculated
# Calculating graph statistics at k = 9
# Progress saved: 35 files processed, 9 k values calculated
#      k  normality_wtihin  normality_between  average_within  average_between  \
# ...

# %%
tuner2 = KNNGraphTuner(
    graph_kernel=gk.WeisfeilerLehman(normalize=False),
    batcher_output_dir='Output/batcher_output_k5'
)
tuner2.calculate_and_graph()
# Out:
# Attempting to load data from GraphBatcher output directory: ./batcher_output_k5
# File not found: ./tuner_output\tuner_results.pkl
# Successfully loaded data from GraphBatcher: 35 files
# Previously calculated results for 0 k values
# Calculating graph statistics at k = 1
# Progress saved: 35 files processed, 1 k values calculated
# Calculating graph statistics at k = 2
# Progress saved: 35 files processed, 2 k values calculated
# Calculating graph statistics at k = 3
# Progress saved: 35 files processed, 3 k values calculated
# Calculating graph statistics at k = 4
# Progress saved: 35 files processed, 4 k values calculated
# Calculating graph statistics at k = 5
# Progress saved: 35 files processed, 5 k values calculated
# Calculating graph statistics at k = 6
# Progress saved: 35 files processed, 6 k values calculated
# Calculating graph statistics at k = 7
# Progress saved: 35 files processed, 7 k values calculated
# Calculating graph statistics at k = 8
# ...

# %%
from thesisv3.classism import MusicFileManager, MusicSegmentAnalyzer, MusicVisualizer, GraphBuilder, GraphBatcher

file_manager = MusicFileManager()
file_manager.display_selector()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\.School\Thesisv3\.venv\Lib\site-packages\tslearn\bases\bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)
# ...

# %%
analyzer = MusicSegmentAnalyzer()
analyzer.load_score(file_manager.selected_file)
analyzer.analyze_segments()
analyzer.preprocess_segments()
# analyzer.nmat

# %%
visualizer = MusicVisualizer(analyzer)
visualizer.visualize_colored_segments()
# Out:
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
# <p style="padding-top: 20px">&nbsp;</p>
