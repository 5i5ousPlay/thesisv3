# %%
# Import the classes
import pandas as pd
from thesisv3.classism import MusicFileManager, MusicSegmentAnalyzer, MusicVisualizer, GraphBuilder, GraphBatcher
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Batch

# %%
# Define your output directory
output_dir = './Output/expectancy_v1'

# Create batchers for k=2 through k=10
for k in range(2, 11):
    print(f"Creating GraphBatcher with k={k}")
    
    # Initialize the batcher with this k value
    batcher = GraphBatcher(k=k, output_dir=output_dir, force_connectivity=True)
    
    # If this is the first run, perform the full batch process
    if k == 2:
        print(f"Running full batch analysis for k={k}")
        batcher.batch()
    else:
        # For subsequent k values, we can just build the graphs
        # since the segments and distance matrices are already calculated
        print(f"Building graphs only for k={k}")
        batcher.build_graphs()
    
    print(f"Completed processing for k={k}")
    print("-" * 40)
# Out:
# Creating GraphBatcher with k=2
# Running full batch analysis for k=2
# Analyzing Bach | Cello Suite No. 1 in G Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|ID
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|P
# Medium|P
# Medium|P
# High|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# High|VR
# High|ID
# Low|ID
# Low|P
# Medium|IP
# Low|IP
# Medium|P
# Low|IP
# Medium|P
# Medium|P
# Low|IP
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|IP
# Low|IP
# Medium|P
# Low|IP
# Medium|P
# Medium|P
# Low|IP
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|ID
# Low|P
# Medium|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|ID
# Low|P
# Medium|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Medium|ID
# Low|P
# Low|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Medium|ID
# Low|P
# Low|ID
# Medium|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|ID
# Low|P
# Medium|ID
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|ID
# Low|P
# Low|ID
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Medium|IP
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Medium|IP
# Medium|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|R
# Low|R
# Low|IP
# Low|R
# Low|R
# Low|IR
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# High|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# High|P
# Low|P
# Medium|IP
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|IP
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|P
# High|IP
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|IP
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|P
# Progress saved: 1 files processed
# Analyzing Bach | Cello Suite No. 2 in D Minor
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# High|R
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|VR
# Low|P
# Medium|P
# High|IP
# Medium|P
# Low|ID
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|IP
# Low|P
# Medium|P
# Medium|P
# Medium|P
# High|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# High|P
# Medium|IP
# Low|P
# Medium|P
# Medium|P
# Medium|P
# High|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|R
# Low|IP
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|R
# Low|P
# Low|P
# VeryLow|rest
# Medium|P
# Medium|P
# Low|P
# High|P
# High|ID
# Medium|P
# Low|P
# VeryLow|rest
# Medium|P
# Medium|P
# Low|P
# High|P
# High|ID
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|ID
# Low|R
# Low|P
# VeryLow|rest
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Medium|P
# Low|P
# Low|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|IR
# Low|P
# Medium|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Medium|P
# Low|P
# Low|P
# High|P
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|IP
# Low|R
# Medium|P
# Low|IP
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|IP
# Low|R
# Low|R
# Low|P
# Medium|P
# Medium|IP
# Low|P
# High|IP
# Medium|IP
# High|P
# Low|P
# Low|P
# Low|R
# Low|P
# Medium|P
# Medium|IP
# Low|P
# High|IP
# Medium|IP
# High|P
# Low|P
# Low|P
# Low|R
# Low|P
# Medium|P
# Medium|P
# Low|P
# High|IP
# Medium|IP
# Medium|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|P
# High|IP
# Low|IP
# Low|R
# Low|P
# Medium|P
# Medium|P
# Low|P
# High|IP
# Medium|IP
# Medium|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|P
# High|IP
# VeryLow|rest
# Progress saved: 2 files processed
# Analyzing Bach | Cello Suite No. 3 in C Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# High|P
# Low|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|IP
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|ID
# Low|P
# Medium|P
# Medium|P
# High|P
# High|P
# Medium|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|VR
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|VR
# Low|R
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|ID
# Medium|P
# Low|P
# Low|P
# Low|ID
# Medium|P
# Medium|VR
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|ID
# Medium|P
# Low|P
# Low|P
# Low|ID
# Medium|P
# Low|VR
# Low|IP
# Medium|P
# VeryLow|M
# Medium|IP
# Medium|P
# VeryLow|M
# VeryLow|rest
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|IR
# Medium|P
# VeryLow|R
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|IR
# Medium|P
# Low|R
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# Low|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|ID
# Medium|P
# Medium|P
# Medium|P
# High|IP
# Medium|P
# High|P
# Medium|ID
# Medium|P
# Medium|P
# Medium|P
# High|IP
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|VR
# Low|P
# Low|VR
# Low|P
# Low|R
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|IP
# Medium|P
# Low|IR
# Medium|P
# Low|R
# Low|P
# Low|VR
# Low|P
# Low|VR
# Low|P
# Low|R
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# High|IP
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# VeryLow|rest
# Low|D
# Low|rest
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# VeryLow|rest
# Low|D
# VeryLow|rest
# Progress saved: 3 files processed
# Analyzing Bach | Cello Suite No. 4 in E-flat Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# High|P
# Medium|P
# Low|R
# Low|R
# High|P
# Low|P
# Low|R
# Low|P
# Low|R
# Low|ID
# Medium|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|R
# High|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# High|P
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# High|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|R
# High|P
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# High|P
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|P
# VeryLow|P
# Medium|P
# Low|VR
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Medium|P
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|VR
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Medium|P
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Medium|ID
# Low|ID
# High|P
# Medium|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|ID
# Low|ID
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|IP
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# Low|P
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# Low|P
# Medium|IP
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Medium|IP
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|P
# High|P
# Low|P
# Medium|P
# Low|P
# High|P
# Low|IP
# Medium|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# High|ID
# Medium|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|P
# High|P
# Low|P
# Medium|P
# Low|P
# High|P
# Low|IP
# Medium|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# High|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# VeryLow|M
# Medium|P
# VeryLow|P
# Low|P
# Medium|IP
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|P
# High|P
# Low|P
# Medium|P
# Low|P
# High|P
# Low|IP
# Medium|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# High|ID
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# Medium|VR
# Medium|ID
# Low|R
# Low|P
# Low|P
# Medium|ID
# Low|R
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|P
# Low|R
# Medium|P
# High|ID
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|R
# Medium|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|P
# Low|R
# Medium|P
# High|ID
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# Progress saved: 4 files processed
# Analyzing Bach | Cello Suite No. 5 in C Minor
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|IP
# VeryLow|rest
# VeryLow|IR
# VeryLow|rest
# Medium|VR
# High|P
# Medium|P
# Medium|VR
# High|P
# Medium|P
# Low|IP
# High|IP
# Medium|P
# High|P
# Low|P
# Medium|P
# High|P
# Low|P
# Medium|P
# Medium|IP
# Medium|P
# Medium|P
# Low|P
# Medium|IP
# High|IP
# High|P
# Low|P
# Medium|P
# Medium|ID
# Low|P
# High|P
# Low|P
# Medium|IP
# Low|R
# Medium|P
# Low|P
# Low|P
# High|IP
# Medium|IP
# High|P
# High|P
# High|IP
# Medium|IP
# High|VR
# Medium|IP
# High|P
# Low|P
# Low|P
# VeryLow|rest
# Medium|VR
# High|P
# Medium|P
# High|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|P
# Medium|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|rest
# VeryLow|rest
# VeryLow|rest
# Medium|P
# VeryLow|rest
# Low|P
# Medium|P
# Medium|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# VeryLow|rest
# Medium|P
# VeryLow|rest
# Low|P
# Medium|P
# Medium|P
# VeryLow|rest
# Low|P
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# High|IP
# Medium|P
# Low|P
# Low|VR
# High|ID
# VeryLow|rest
# Low|P
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# High|IP
# Medium|P
# Low|P
# Low|VR
# High|ID
# VeryLow|rest
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# High|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# Medium|P
# Low|VR
# Medium|P
# High|P
# VeryLow|rest
# Low|P
# Medium|P
# Low|VR
# Medium|P
# High|P
# VeryLow|rest
# Low|P
# Low|R
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Medium|P
# Low|IP
# Low|R
# Low|R
# Low|R
# Low|R
# Medium|P
# Low|IP
# Low|R
# Low|R
# Low|R
# Low|IP
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# Low|IP
# VeryLow|rest
# Low|VR
# VeryLow|rest
# VeryLow|P
# Low|R
# Low|IP
# Low|R
# Low|R
# Low|IP
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# Low|IP
# VeryLow|rest
# Low|VR
# VeryLow|rest
# VeryLow|P
# Low|R
# Low|R
# Medium|P
# Medium|ID
# Medium|P
# Medium|ID
# High|ID
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# High|P
# High|P
# High|P
# Medium|P
# Medium|P
# High|P
# High|IP
# Low|P
# Medium|P
# High|ID
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# High|P
# High|P
# High|P
# Medium|P
# Medium|P
# High|P
# High|IP
# Low|P
# Medium|P
# Low|R
# Low|R
# Low|R
# Low|R
# Medium|P
# Medium|IP
# VeryLow|R
# Medium|IP
# Low|R
# Low|IP
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# Low|IP
# VeryLow|rest
# Low|VR
# VeryLow|rest
# VeryLow|P
# Low|R
# Low|IP
# Low|IP
# Low|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|R
# High|P
# Low|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|R
# Medium|P
# Medium|P
# Medium|P
# Low|P
# VeryHigh|ID
# Low|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|R
# Medium|P
# Medium|P
# Medium|P
# Low|P
# VeryHigh|ID
# Low|P
# High|P
# Medium|P
# Low|P
# Low|P
# VeryLow|R
# Progress saved: 5 files processed
# Analyzing Bach | Cello Suite No. 6 in D Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# High|P
# High|ID
# High|IP
# High|P
# High|ID
# High|VR
# High|IP
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|ID
# Low|ID
# High|P
# Low|P
# Low|P
# High|IP
# Low|P
# Low|P
# Low|P
# High|ID
# Low|P
# Medium|IP
# High|IP
# Low|P
# Low|ID
# High|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# High|ID
# Low|P
# Medium|IP
# High|IP
# Low|P
# Low|ID
# High|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# High|IP
# Medium|P
# Medium|P
# Low|P
# Medium|IP
# Low|ID
# High|ID
# High|P
# Medium|P
# Low|IP
# Low|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# High|IP
# Medium|P
# Medium|P
# Low|P
# Medium|IP
# Low|ID
# High|ID
# High|P
# Medium|P
# Low|IP
# Low|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# VeryLow|R
# Low|VR
# Low|VR
# Low|VR
# Low|IP
# Low|P
# High|P
# Medium|VR
# Low|R
# Medium|P
# Medium|P
# Low|P
# VeryLow|VR
# Low|R
# Low|VR
# Low|VR
# Low|VR
# Low|IP
# Low|P
# High|P
# Medium|VR
# Low|R
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Medium|P
# High|ID
# Low|P
# Low|P
# Low|P
# Low|R
# Low|VR
# Low|R
# High|P
# High|P
# High|IP
# Low|R
# Low|P
# Low|P
# Low|P
# High|P
# Medium|P
# Low|P
# Low|R
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Medium|P
# High|ID
# Low|P
# Low|P
# Low|P
# Low|R
# Low|VR
# Low|R
# High|P
# High|P
# High|IP
# Low|R
# Low|P
# Low|P
# Low|P
# High|P
# Medium|P
# Low|P
# Low|R
# Medium|P
# Medium|P
# Low|P
# VeryLow|VR
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|R
# VeryLow|rest
# VeryLow|rest
# Low|IP
# VeryLow|rest
# Medium|IP
# Medium|IP
# Low|IP
# VeryLow|rest
# VeryLow|rest
# Low|R
# VeryLow|rest
# VeryLow|rest
# Low|IP
# VeryLow|rest
# Medium|IP
# Medium|IP
# Low|IP
# VeryLow|rest
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# High|P
# High|IP
# Low|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# High|P
# High|IP
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# High|P
# High|IP
# Low|P
# Low|P
# Low|P
# Low|R
# Medium|P
# Medium|P
# High|P
# High|P
# Low|IP
# Low|P
# Medium|P
# Low|P
# Medium|ID
# Low|P
# Medium|P
# Low|R
# Low|R
# Medium|P
# Medium|P
# High|P
# High|P
# Low|IP
# Low|P
# Medium|P
# Low|P
# Medium|ID
# Low|P
# Medium|P
# Medium|P
# High|P
# Low|P
# Low|R
# Low|P
# Medium|P
# Low|R
# High|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# High|P
# High|P
# Low|IP
# Medium|P
# Low|P
# Medium|P
# High|P
# Low|P
# Low|R
# Low|P
# Medium|P
# Low|R
# High|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# High|P
# High|P
# Low|IP
# Medium|P
# Low|P
# Progress saved: 6 files processed
# Analyzing Chopin | Étude Op. 10 No. 1 'Waterfall'
# The k‑NN graph is disjoint. Ensuring connectivity…
# VeryLow|P
# VeryLow|P
# VeryLow|R
# VeryLow|IR
# VeryLow|rest
# Low|ID
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# Low|P
# Low|P
# VeryLow|rest
# Low|IR
# Low|IR
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|M
# Low|P
# VeryLow|rest
# Low|IR
# VeryLow|rest
# Low|ID
# VeryLow|rest
# VeryLow|IR
# VeryLow|IR
# VeryLow|rest
# Low|ID
# VeryLow|rest
# VeryLow|M
# VeryLow|IR
# VeryLow|rest
# Low|ID
# VeryLow|rest
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|IR
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# Low|P
# Low|P
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# VeryLow|rest
# VeryLow|IP
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# VeryLow|P
# VeryLow|M
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|R
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# VeryLow|P
# VeryLow|R
# VeryLow|IR
# VeryLow|rest
# Low|ID
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# Low|P
# Low|P
# VeryLow|rest
# Low|IR
# Low|IR
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# Low|IR
# Low|P
# VeryLow|rest
# VeryLow|M
# VeryLow|IR
# VeryLow|rest
# Low|ID
# VeryLow|rest
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|rest
# VeryLow|IR
# Low|P
# Low|P
# VeryLow|P
# Low|P
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|rest
# Low|IR
# VeryLow|rest
# VeryLow|rest
# Progress saved: 7 files processed
# Analyzing Chopin | Étude Op. 10 No. 2 'Chromatic'
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# High|IP
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# VeryLow|M
# Low|P
# Low|P
# VeryLow|M
# Low|P
# Low|P
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# VeryLow|rest
# High|IP
# Low|VR
# VeryLow|M
# Low|IP
# High|IP
# Medium|IP
# VeryLow|M
# Low|IP
# High|IP
# Medium|IP
# VeryLow|M
# Medium|IP
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Progress saved: 8 files processed
# Analyzing Chopin | Étude Op. 10 No. 4 'Torrent'
# The k‑NN graph is disjoint. Ensuring connectivity…
# Medium|P
# Low|R
# VeryLow|R
# VeryLow|P
# Low|P
# VeryLow|R
# VeryLow|M
# Low|IP
# High|IP
# Low|R
# VeryLow|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# Low|IP
# VeryLow|M
# Low|IP
# Low|IP
# High|P
# High|P
# High|IP
# Low|IP
# Medium|IP
# Medium|IP
# Low|R
# Low|R
# Low|R
# Low|P
# Low|IP
# Low|IP
# Medium|P
# High|P
# High|P
# Low|R
# VeryLow|R
# VeryLow|P
# Low|P
# VeryLow|R
# VeryLow|M
# High|IP
# Low|R
# VeryLow|P
# Low|R
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|R
# Low|R
# VeryLow|P
# Progress saved: 9 files processed
# Analyzing Chopin | Étude Op. 10 No. 5 'Black Keys'
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|R
# Low|ID
# Low|R
# Low|R
# Low|ID
# Low|R
# Low|ID
# Low|ID
# Low|R
# Low|R
# Low|R
# Low|ID
# Low|P
# Low|P
# Low|ID
# VeryLow|R
# Low|ID
# Low|ID
# Low|R
# Low|R
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Low|P
# Low|R
# Low|P
# Low|IR
# Low|R
# Low|R
# Low|ID
# Low|R
# Low|ID
# Low|R
# Low|ID
# Low|ID
# Low|R
# Low|R
# Low|ID
# Low|ID
# Low|ID
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|P
# VeryLow|ID
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Progress saved: 10 files processed
# Analyzing Chopin | Étude Op. 10 No. 6 'Lament'
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Low|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# High|P
# VeryLow|rest
# Medium|P
# High|IP
# Medium|P
# Medium|P
# Low|ID
# Low|IP
# Medium|ID
# Medium|P
# Medium|ID
# Medium|IP
# Low|R
# Low|IP
# High|IP
# Medium|IP
# Medium|IP
# Medium|IP
# Medium|IP
# Medium|IP
# Medium|IP
# Medium|IP
# High|IP
# Low|IP
# Medium|IP
# Low|R
# Low|IP
# Medium|IP
# High|IP
# Low|P
# Low|P
# High|P
# VeryLow|M
# Low|P
# Low|ID
# Progress saved: 11 files processed
# Analyzing Chopin | Étude Op. 10 No. 7 'Toccata'
# The k‑NN graph is disjoint. Ensuring connectivity…
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|ID
# Low|ID
# Low|R
# Low|R
# Medium|R
# Low|ID
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|ID
# Low|R
# Low|R
# Low|ID
# Low|ID
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# VeryLow|M
# Progress saved: 12 files processed
# Analyzing Chopin | Étude Op. 10 No. 8 'Sunshine'
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Medium|R
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# Medium|ID
# High|IP
# High|IP
# Low|P
# Low|IP
# Low|R
# Low|R
# Medium|ID
# Medium|IP
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# Progress saved: 13 files processed
# Analyzing Chopin | Étude Op. 10 No. 9
# The k‑NN graph is disjoint. Ensuring connectivity…
# VeryLow|d
# Low|P
# VeryLow|M
# Low|P
# VeryLow|d
# Low|P
# VeryLow|M
# Low|P
# Low|P
# VeryLow|M
# Low|P
# VeryLow|rest
# High|D
# Medium|P
# Low|D
# High|ID
# Low|ID
# VeryLow|M
# Low|P
# VeryLow|M
# Low|P
# VeryLow|d
# Low|P
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# High|P
# High|D
# Medium|P
# Low|D
# Low|P
# Low|P
# Low|R
# Progress saved: 14 files processed
# Analyzing Chopin | Étude Op. 10 No. 10
# Low|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# Low|ID
# Low|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|R
# Low|ID
# VeryLow|R
# Low|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|ID
# Progress saved: 15 files processed
# Analyzing Chopin | Étude Op. 25 No. 2 'The Bees'
# The k‑NN graph is disjoint. Ensuring connectivity…
# Medium|IP
# Medium|IP
# High|IP
# High|P
# Medium|ID
# High|P
# High|P
# High|IP
# Medium|IP
# High|IP
# High|ID
# High|P
# High|P
# High|P
# Medium|P
# High|P
# High|ID
# Medium|IP
# High|P
# High|ID
# High|P
# High|P
# High|IP
# Medium|IP
# High|P
# High|ID
# Medium|P
# High|P
# High|P
# High|P
# High|P
# High|ID
# Medium|P
# High|P
# High|P
# High|ID
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# High|P
# Low|P
# High|P
# Low|P
# High|ID
# Medium|IP
# High|IP
# High|P
# High|ID
# Medium|P
# Medium|P
# High|P
# High|IP
# Medium|IP
# High|P
# Medium|P
# High|P
# High|IP
# Medium|IP
# Low|P
# Medium|P
# Low|IP
# Progress saved: 16 files processed
# Analyzing Chopin | Étude Op. 25 No. 9 'Butterfly'
# The k‑NN graph is disjoint. Ensuring connectivity…
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|P
# VeryLow|R
# VeryLow|R
# Low|P
# VeryLow|VR
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|IP
# VeryLow|R
# Low|R
# VeryLow|M
# VeryLow|IP
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|IR
# VeryLow|IP
# Low|P
# VeryLow|M
# VeryLow|R
# VeryLow|P
# VeryLow|M
# VeryLow|R
# VeryLow|M
# Low|R
# VeryLow|rest
# Progress saved: 17 files processed
# Analyzing Chopin | Étude Op. 25 No. 11 'Winter Wind'
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|D
# Medium|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# VeryLow|rest
# Medium|R
# Low|R
# Low|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|D
# Medium|D
# Low|D
# Low|ID
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|P
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# VeryLow|rest
# Medium|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|ID
# Low|P
# Progress saved: 18 files processed
# Analyzing Chopin | Étude Op. 25 No. 12 'Ocean'
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# VeryLow|M
# Low|R
# Low|VP
# VeryLow|rest
# Low|ID
# VeryLow|M
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|ID
# VeryLow|M
# Low|R
# VeryLow|M
# Low|ID
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|VP
# Low|P
# Low|P
# Low|VP
# Low|P
# Low|VP
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# VeryLow|M
# Low|R
# Low|VP
# VeryLow|rest
# Low|ID
# VeryLow|M
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|P
# Low|P
# VeryLow|ID
# Low|P
# Low|P
# VeryLow|ID
# Low|ID
# Progress saved: 19 files processed
# Analyzing Chopin | Waltz Op. 34 No. 1 in A-flat Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|D
# Low|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|M
# Low|D
# Low|D
# Medium|D
# VeryLow|d
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Medium|P
# VeryLow|d
# VeryLow|M
# Low|P
# VeryLow|M
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# Low|P
# VeryLow|M
# VeryLow|d
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# Low|P
# VeryLow|M
# High|D
# Low|ID
# Low|P
# Low|P
# VeryLow|M
# VeryLow|d
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# Low|D
# Low|D
# Low|R
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|ID
# VeryLow|M
# Low|ID
# Low|P
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# Low|D
# Low|D
# Medium|D
# VeryLow|d
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# Medium|P
# VeryLow|M
# VeryLow|M
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|ID
# High|ID
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# High|ID
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Progress saved: 20 files processed
# Analyzing Chopin | Waltz Op. 34 No. 2 in A Minor
# The k‑NN graph is disjoint. Ensuring connectivity…
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Medium|IP
# Low|P
# VeryLow|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# VeryLow|IP
# VeryLow|M
# VeryLow|P
# VeryLow|M
# VeryLow|IP
# VeryLow|M
# Medium|P
# Medium|P
# Low|VP
# Low|P
# Medium|P
# Low|P
# VeryLow|M
# Medium|IP
# Low|P
# VeryLow|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# VeryLow|IP
# VeryLow|M
# VeryLow|P
# VeryLow|M
# VeryLow|IP
# VeryLow|M
# Medium|P
# Medium|P
# Low|VP
# Low|P
# Medium|P
# Low|P
# VeryLow|M
# VeryLow|rest
# VeryLow|rest
# VeryLow|d
# VeryLow|M
# VeryLow|M
# VeryLow|M
# VeryLow|VR
# VeryLow|M
# VeryLow|VR
# VeryLow|M
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|d
# VeryLow|rest
# Progress saved: 21 files processed
# Analyzing Chopin | Waltz Op. 34 No. 3 in F Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|D
# Medium|D
# High|P
# Low|P
# Low|P
# Low|P
# VeryLow|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|P
# VeryLow|P
# Low|IP
# Low|IP
# Low|P
# VeryLow|P
# Medium|P
# Medium|ID
# Low|IP
# Medium|IP
# Low|P
# VeryLow|P
# Medium|P
# Medium|IP
# Low|IP
# Low|IP
# High|IP
# Low|P
# Low|P
# Low|P
# High|IP
# High|IP
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Progress saved: 22 files processed
# Analyzing Chopin | Waltz Op. 64 No. 1 'Minute Waltz'
# The k‑NN graph is disjoint. Ensuring connectivity…
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# High|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# High|ID
# Low|R
# Medium|P
# High|ID
# Low|R
# VeryLow|R
# Low|R
# VeryLow|IR
# Medium|R
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# High|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# Progress saved: 23 files processed
# Analyzing Chopin | Waltz Op. 64 No. 2 in C Minor
# The k‑NN graph is disjoint. Ensuring connectivity…
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|R
# Low|VR
# Medium|IP
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|R
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|R
# Low|VR
# Medium|IP
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|R
# Low|P
# VeryLow|d
# Low|P
# Low|P
# Low|P
# Low|P
# Progress saved: 24 files processed
# Analyzing Chopin | Waltz Op. 64 No. 3 in A-flat Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Low|IP
# High|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|IP
# High|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# Low|IP
# Medium|P
# Low|R
# Low|R
# Low|R
# Low|P
# High|ID
# Medium|P
# Low|ID
# Medium|P
# Medium|P
# Low|ID
# Medium|D
# VeryLow|R
# Low|P
# VeryLow|rest
# Low|IP
# VeryLow|M
# VeryLow|M
# VeryLow|M
# VeryLow|D
# Low|P
# Low|P
# Low|IP
# High|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|IP
# High|P
# Low|P
# High|VR
# Medium|IP
# Low|P
# Low|VR
# Medium|P
# Low|IP
# Low|R
# Low|R
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Progress saved: 25 files processed
# Analyzing Chopin | Waltz Op. 42 in A Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# High|ID
# High|ID
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Low|R
# Low|R
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# VeryLow|M
# Low|ID
# VeryLow|M
# Low|ID
# VeryLow|M
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|P
# VeryLow|rest
# Medium|ID
# Medium|IP
# Low|P
# Low|R
# Medium|R
# Low|R
# Low|R
# Low|R
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# Medium|P
# Low|P
# Low|P
# High|ID
# VeryLow|M
# VeryLow|M
# VeryLow|d
# VeryLow|M
# Low|P
# Low|P
# VeryLow|M
# VeryLow|M
# VeryLow|d
# VeryLow|M
# VeryLow|d
# VeryLow|M
# Low|R
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Progress saved: 26 files processed
# Analyzing Mozart | Minuet in G Major
# Low|P
# Medium|ID
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Progress saved: 27 files processed
# Analyzing Mozart | Piano Sonata No. 10 in C Major, K. 330 (1st movement)
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|R
# VeryLow|R
# Low|P
# Low|P
# Low|P
# VeryLow|ID
# Medium|P
# Low|P
# Low|P
# Medium|D
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# Medium|P
# Low|P
# Low|ID
# Low|ID
# Low|ID
# Low|R
# Low|P
# Low|ID
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Medium|P
# VeryLow|M
# High|D
# VeryLow|M
# Low|P
# Medium|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# VeryLow|R
# VeryLow|M
# VeryLow|M
# Progress saved: 28 files processed
# Analyzing Mozart | Piano Sonata No. 11 in A Major, K. 331 'Rondo Alla Turca'
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|ID
# Medium|P
# Low|P
# High|P
# High|P
# High|P
# Medium|P
# Medium|P
# Low|VR
# High|P
# High|ID
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# VeryLow|R
# VeryLow|R
# Low|R
# VeryLow|P
# Medium|ID
# Low|R
# VeryLow|P
# High|P
# Low|ID
# Low|P
# High|ID
# Low|ID
# VeryLow|P
# High|P
# Low|ID
# Progress saved: 29 files processed
# Analyzing Satie | Gnossienne No. 1
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Low|P
# VeryLow|IP
# Low|P
# Low|P
# Low|IP
# High|P
# Low|P
# Medium|ID
# High|P
# Low|P
# Medium|ID
# High|P
# Medium|P
# High|P
# Medium|ID
# Low|P
# High|ID
# Low|P
# Medium|ID
# High|P
# Low|P
# Medium|ID
# High|P
# Medium|P
# High|P
# Medium|ID
# Progress saved: 30 files processed
# Analyzing Satie | Gnossienne No. 2
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|ID
# High|ID
# VeryLow|rest
# High|ID
# VeryLow|rest
# High|P
# High|D
# VeryLow|P
# High|P
# Medium|D
# VeryLow|rest
# Medium|P
# High|D
# VeryLow|rest
# Medium|P
# High|D
# VeryLow|rest
# High|P
# High|D
# VeryLow|P
# Medium|D
# High|ID
# VeryLow|rest
# Progress saved: 31 files processed
# Analyzing Satie | Gnossienne No. 3
# Low|IP
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|IP
# Low|IP
# Low|P
# Medium|P
# VeryLow|IP
# High|P
# VeryLow|P
# Medium|R
# Low|IP
# Low|IP
# Progress saved: 32 files processed
# Analyzing Satie | Gnossienne No. 4
# VeryLow|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|P
# VeryLow|P
# Low|ID
# Low|P
# VeryLow|rest
# VeryLow|rest
# Progress saved: 33 files processed
# Analyzing Ysaÿe | Violin Sonata No. 1 in G Minor
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# VeryLow|VR
# VeryLow|rest
# VeryLow|P
# VeryLow|M
# VeryLow|M
# VeryLow|P
# VeryLow|M
# VeryLow|rest
# Low|R
# VeryLow|rest
# Low|IR
# Low|IR
# Low|P
# High|ID
# High|IP
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# High|P
# VeryLow|M
# Low|P
# VeryLow|P
# VeryLow|M
# VeryLow|M
# VeryLow|d
# VeryLow|rest
# VeryLow|M
# VeryLow|R
# VeryLow|M
# Low|IR
# VeryLow|VP
# Low|IR
# Low|VP
# Low|IR
# Low|VP
# Low|P
# Low|IR
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# VeryLow|P
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|IR
# VeryLow|M
# VeryLow|M
# VeryLow|P
# VeryLow|rest
# Low|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|VP
# Low|R
# Low|IR
# VeryLow|rest
# Medium|R
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# VeryLow|IP
# Low|P
# Low|IR
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|M
# Low|P
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|ID
# Medium|P
# High|ID
# High|ID
# High|P
# Medium|ID
# VeryLow|P
# Low|P
# Low|R
# Low|R
# VeryLow|P
# Low|R
# Low|P
# Low|P
# Low|R
# Low|R
# Low|R
# Low|P
# Low|P
# Low|R
# Medium|P
# VeryLow|rest
# VeryLow|rest
# Low|P
# VeryLow|P
# VeryLow|R
# Low|ID
# VeryLow|M
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|R
# Low|P
# Medium|P
# Low|P
# VeryLow|R
# Low|P
# VeryLow|rest
# VeryLow|M
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|IP
# VeryLow|M
# VeryLow|D
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|ID
# VeryLow|R
# Low|ID
# Low|ID
# VeryLow|ID
# Low|P
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|P
# Low|P
# VeryLow|P
# Medium|P
# VeryLow|P
# Medium|P
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|M
# VeryLow|R
# Low|P
# Low|P
# Low|R
# Medium|R
# Medium|R
# Medium|R
# Low|P
# Low|ID
# Low|ID
# Medium|ID
# Low|ID
# VeryLow|rest
# VeryLow|M
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|IP
# VeryLow|M
# VeryLow|D
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|ID
# VeryLow|ID
# Low|P
# Low|P
# VeryLow|M
# VeryLow|R
# Low|R
# Low|R
# Low|IR
# Low|P
# Low|R
# Low|R
# Low|R
# Low|ID
# Low|R
# Low|P
# Low|IR
# Low|IR
# Low|R
# Medium|R
# Low|R
# Low|P
# Medium|R
# Low|P
# Low|R
# Low|P
# Low|ID
# Low|R
# Low|R
# VeryLow|rest
# Medium|P
# Medium|ID
# Low|ID
# Low|R
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|P
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|P
# VeryLow|R
# Low|R
# Low|R
# VeryLow|R
# Progress saved: 34 files processed
# Analyzing Ysaÿe | Violin Sonata No. 2 in A Minor
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|ID
# Low|R
# VeryLow|R
# Low|P
# Low|R
# VeryLow|R
# Low|P
# Low|R
# Medium|VR
# Medium|P
# Low|R
# Low|R
# Low|P
# Low|ID
# VeryLow|M
# Low|R
# Low|R
# VeryLow|P
# VeryLow|R
# VeryLow|R
# Low|P
# Medium|R
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|ID
# Low|R
# VeryLow|ID
# VeryLow|rest
# Low|R
# Low|R
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|R
# VeryLow|P
# Medium|P
# Low|P
# High|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|IP
# Medium|P
# Low|R
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|rest
# VeryLow|rest
# VeryLow|M
# VeryLow|rest
# Medium|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|P
# High|P
# Low|VR
# Low|P
# Low|P
# VeryLow|IR
# Low|P
# Low|R
# Low|P
# Medium|ID
# Low|P
# VeryLow|rest
# Low|P
# High|ID
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Medium|P
# Low|P
# Low|VR
# Low|ID
# Low|ID
# Low|P
# Low|R
# Medium|P
# Low|R
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|VR
# Low|P
# Low|R
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# VeryLow|P
# VeryLow|M
# Low|P
# VeryLow|d
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# Medium|R
# VeryLow|rest
# Low|R
# Low|P
# VeryLow|P
# VeryLow|IP
# VeryLow|R
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# Low|IP
# VeryLow|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# VeryLow|rest
# Low|R
# Low|R
# Low|R
# Low|R
# Low|IR
# VeryLow|P
# VeryLow|M
# Low|R
# VeryLow|rest
# VeryLow|P
# VeryLow|rest
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Low|ID
# Low|P
# Low|VR
# Low|R
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|IP
# Low|D
# Low|D
# Low|P
# Low|ID
# Low|P
# VeryLow|P
# VeryLow|rest
# VeryLow|IP
# VeryLow|P
# Low|R
# Low|D
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|M
# VeryLow|P
# VeryLow|IP
# VeryLow|R
# VeryLow|R
# VeryLow|rest
# VeryLow|P
# VeryLow|R
# VeryLow|IP
# Low|ID
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# VeryLow|rest
# Progress saved: 35 files processed
# Analyzing Ysaÿe | Violin Sonata No. 3 in D Minor
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Low|P
# Low|R
# VeryLow|M
# VeryLow|IR
# Low|P
# VeryLow|M
# VeryLow|M
# Low|R
# VeryLow|M
# Low|R
# Low|IP
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|R
# Low|R
# Low|ID
# Low|R
# Low|R
# VeryLow|ID
# Low|P
# VeryLow|R
# VeryLow|M
# VeryLow|M
# Low|P
# Low|R
# Low|VR
# Medium|P
# Medium|IP
# Medium|IP
# Medium|P
# Medium|IP
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|ID
# Low|ID
# Low|ID
# Low|IP
# Low|ID
# Medium|ID
# Medium|P
# High|ID
# Low|P
# High|ID
# Low|ID
# Low|P
# High|ID
# Low|ID
# High|ID
# High|ID
# Low|ID
# Medium|ID
# Medium|ID
# Low|R
# Low|R
# Low|ID
# Medium|ID
# Medium|P
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# VeryLow|rest
# Low|R
# VeryLow|M
# Medium|IP
# Low|P
# VeryLow|P
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|IR
# High|IP
# Medium|P
# High|P
# VeryLow|P
# VeryLow|rest
# VeryLow|R
# VeryLow|M
# Low|IP
# Low|R
# Low|IP
# Medium|R
# Medium|IP
# Medium|P
# Low|IP
# VeryLow|VR
# VeryLow|IR
# Low|P
# Low|R
# Low|R
# VeryLow|ID
# Low|ID
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|D
# VeryLow|rest
# VeryLow|D
# VeryLow|rest
# Low|R
# VeryLow|rest
# VeryLow|rest
# VeryLow|R
# Progress saved: 36 files processed
# Analyzing Ysaÿe | Violin Sonata No. 4 in E Minor
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# VeryLow|R
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|R
# VeryLow|P
# Low|P
# Medium|P
# Low|P
# VeryLow|P
# VeryLow|P
# Low|ID
# Low|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Medium|P
# VeryLow|P
# Low|P
# VeryLow|IR
# VeryLow|rest
# Low|P
# VeryLow|P
# Low|VR
# VeryLow|d
# Low|P
# High|P
# Low|IP
# VeryLow|rest
# Low|IP
# Low|P
# Low|P
# Low|P
# VeryLow|R
# Medium|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|P
# VeryLow|R
# VeryLow|M
# Low|P
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|R
# VeryLow|P
# Low|R
# VeryLow|rest
# VeryLow|VR
# VeryLow|rest
# VeryLow|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|P
# VeryLow|rest
# VeryLow|rest
# Low|P
# VeryLow|M
# VeryLow|rest
# Low|P
# VeryLow|M
# VeryLow|rest
# Low|P
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|IR
# VeryLow|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# VeryLow|rest
# Low|P
# VeryLow|d
# VeryLow|M
# VeryLow|IR
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|d
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Low|P
# Medium|P
# Medium|P
# Low|R
# Low|P
# Low|R
# Low|P
# Low|P
# Low|IR
# VeryLow|VR
# Low|R
# VeryLow|R
# Low|R
# VeryLow|R
# Low|R
# VeryLow|R
# Low|VR
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# VeryLow|P
# Low|P
# Low|P
# VeryLow|P
# Medium|P
# Low|P
# Medium|P
# VeryLow|d
# VeryLow|M
# Low|R
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|R
# VeryLow|R
# Progress saved: 37 files processed
# Analyzing Ysaÿe | Violin Sonata No. 5 in G Major
# VeryLow|ID
# VeryLow|M
# VeryLow|D
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|R
# Low|R
# Low|P
# Low|P
# VeryLow|IR
# VeryLow|IR
# Low|P
# Low|IP
# VeryLow|M
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# Low|P
# VeryLow|P
# VeryLow|P
# Low|ID
# VeryLow|P
# Low|ID
# Low|P
# VeryLow|R
# VeryLow|d
# VeryLow|M
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Medium|P
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|IR
# Low|R
# Low|IR
# Low|R
# VeryLow|M
# VeryLow|M
# VeryLow|IR
# VeryLow|rest
# VeryLow|rest
# Low|VR
# VeryLow|ID
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|rest
# VeryLow|d
# VeryLow|rest
# Low|P
# VeryLow|P
# Medium|P
# VeryLow|M
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# VeryLow|M
# VeryLow|IR
# Low|R
# VeryLow|M
# VeryLow|rest
# Low|P
# VeryLow|d
# VeryLow|ID
# Low|R
# Low|P
# Low|P
# Low|VR
# Low|R
# VeryLow|rest
# Low|P
# Low|P
# VeryLow|ID
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# VeryLow|ID
# Low|ID
# Low|ID
# Low|ID
# Low|ID
# VeryLow|M
# VeryLow|rest
# Medium|P
# Low|ID
# Low|R
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|IP
# VeryLow|rest
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# Low|ID
# VeryLow|rest
# Low|P
# VeryLow|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# Low|R
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|P
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Medium|P
# Low|R
# Low|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# VeryLow|IP
# VeryLow|rest
# VeryLow|M
# Low|R
# VeryLow|P
# Low|P
# Low|P
# Medium|P
# VeryLow|R
# Low|P
# Medium|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# Low|P
# Low|R
# Low|D
# Low|D
# Medium|D
# Low|D
# Medium|D
# Low|D
# Low|R
# Low|P
# High|P
# Low|P
# Low|R
# Low|R
# Low|P
# Medium|P
# High|P
# VeryLow|M
# Low|P
# Low|P
# VeryLow|rest
# Progress saved: 38 files processed
# Analyzing Ysaÿe | Violin Sonata No. 6 in E Major
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|ID
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# Low|P
# Low|R
# Low|P
# Low|P
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|P
# Medium|P
# Medium|IP
# VeryLow|M
# VeryLow|rest
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|IR
# Low|R
# Low|R
# Low|IP
# Low|R
# VeryLow|R
# Low|R
# Low|P
# Low|IP
# Low|R
# VeryLow|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|R
# Low|R
# Low|R
# Low|R
# Low|IP
# VeryLow|VR
# VeryLow|rest
# Low|R
# Low|ID
# Medium|IP
# Medium|ID
# Low|ID
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# High|ID
# Low|P
# Low|P
# VeryLow|IR
# Low|R
# Medium|P
# Low|R
# High|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Medium|P
# Low|P
# Low|P
# VeryLow|M
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# Low|R
# Low|P
# Low|IR
# Low|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# Low|P
# Low|R
# Low|R
# Low|R
# Medium|P
# Low|IP
# Low|IP
# Low|R
# Low|ID
# Low|P
# Low|ID
# Low|ID
# Low|P
# Low|P
# Progress saved: 39 files processed
# Completed processing for k=2
# ----------------------------------------
# Creating GraphBatcher with k=3
# Loaded previous progress: 39 files already processed
# Building graphs only for k=3
# Building graph for Bach | Cello Suite No. 1 in G Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|ID
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|P
# Medium|P
# Medium|P
# High|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# High|VR
# High|ID
# Low|ID
# Low|P
# Medium|IP
# Low|IP
# Medium|P
# Low|IP
# Medium|P
# Medium|P
# Low|IP
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|IP
# Low|IP
# Medium|P
# Low|IP
# Medium|P
# Medium|P
# Low|IP
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|ID
# Low|P
# Medium|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|ID
# Low|P
# Medium|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Medium|ID
# Low|P
# Low|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Medium|ID
# Low|P
# Low|ID
# Medium|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|ID
# Low|P
# Medium|ID
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|ID
# Low|P
# Low|ID
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Medium|IP
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Medium|IP
# Medium|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|R
# Low|R
# Low|IP
# Low|R
# Low|R
# Low|IR
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# High|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# High|P
# Low|P
# Medium|IP
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|IP
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|P
# High|IP
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|IP
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|P
# Progress saved: 39 files processed
# Building graph for Bach | Cello Suite No. 2 in D Minor
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# High|R
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|VR
# Low|P
# Medium|P
# High|IP
# Medium|P
# Low|ID
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|IP
# Low|P
# Medium|P
# Medium|P
# Medium|P
# High|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# High|P
# Medium|IP
# Low|P
# Medium|P
# Medium|P
# Medium|P
# High|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|R
# Low|IP
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|R
# Low|P
# Low|P
# VeryLow|rest
# Medium|P
# Medium|P
# Low|P
# High|P
# High|ID
# Medium|P
# Low|P
# VeryLow|rest
# Medium|P
# Medium|P
# Low|P
# High|P
# High|ID
# Medium|P
# Low|P
# Low|P
# VeryLow|rest
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|ID
# Low|R
# Low|P
# VeryLow|rest
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Medium|P
# Low|P
# Low|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|IR
# Low|P
# Medium|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Medium|P
# Low|P
# Low|P
# High|P
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|IP
# Low|R
# Medium|P
# Low|IP
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|IP
# Low|R
# Low|R
# Low|P
# Medium|P
# Medium|IP
# Low|P
# High|IP
# Medium|IP
# High|P
# Low|P
# Low|P
# Low|R
# Low|P
# Medium|P
# Medium|IP
# Low|P
# High|IP
# Medium|IP
# High|P
# Low|P
# Low|P
# Low|R
# Low|P
# Medium|P
# Medium|P
# Low|P
# High|IP
# Medium|IP
# Medium|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|P
# High|IP
# Low|IP
# Low|R
# Low|P
# Medium|P
# Medium|P
# Low|P
# High|IP
# Medium|IP
# Medium|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|P
# High|IP
# VeryLow|rest
# Progress saved: 39 files processed
# Building graph for Bach | Cello Suite No. 3 in C Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# High|P
# Low|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|IP
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|ID
# Low|P
# Medium|P
# Medium|P
# High|P
# High|P
# Medium|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# High|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|ID
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|VR
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|VR
# Low|R
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|ID
# Medium|P
# Low|P
# Low|P
# Low|ID
# Medium|P
# Medium|VR
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|ID
# Medium|P
# Low|P
# Low|P
# Low|ID
# Medium|P
# Low|VR
# Low|IP
# Medium|P
# VeryLow|M
# Medium|IP
# Medium|P
# VeryLow|M
# VeryLow|rest
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|IR
# Medium|P
# VeryLow|R
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|IR
# Medium|P
# Low|R
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# Low|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|ID
# Medium|P
# Medium|P
# Medium|P
# High|IP
# Medium|P
# High|P
# Medium|ID
# Medium|P
# Medium|P
# Medium|P
# High|IP
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|R
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|VR
# Low|P
# Low|VR
# Low|P
# Low|R
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|IP
# Medium|P
# Low|IR
# Medium|P
# Low|R
# Low|P
# Low|VR
# Low|P
# Low|VR
# Low|P
# Low|R
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# High|IP
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# VeryLow|rest
# Low|D
# Low|rest
# Low|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Medium|P
# Low|P
# VeryLow|rest
# Low|D
# VeryLow|rest
# Progress saved: 39 files processed
# Building graph for Bach | Cello Suite No. 4 in E-flat Major
# The k‑NN graph is disjoint. Ensuring connectivity…
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|P
# Low|R
# Low|R
# Low|R
# Low|VR
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# High|P
# Medium|P
# Low|R
# Low|R
# High|P
# Low|P
# Low|R
# Low|P
# Low|R
# Low|ID
# Medium|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|R
# High|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# High|P
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# High|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|R
# High|P
# High|P
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# High|P
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|P
# ...
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|R
# Low|P
# VeryLow|d
# Low|P
# Low|P
# Low|P
# Low|P
# Progress saved: 39 files processed
# Building graph for Chopin | Waltz Op. 64 No. 3 in A-flat Major
# Low|P
# Low|IP
# High|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|IP
# High|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Medium|IP
# Medium|P
# Low|P
# Low|IP
# Medium|P
# Low|R
# Low|R
# Low|R
# Low|P
# High|ID
# Medium|P
# Low|ID
# Medium|P
# Medium|P
# Low|ID
# Medium|D
# VeryLow|R
# Low|P
# VeryLow|rest
# Low|IP
# VeryLow|M
# VeryLow|M
# VeryLow|M
# VeryLow|D
# Low|P
# Low|P
# Low|IP
# High|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|IP
# High|P
# Low|P
# High|VR
# Medium|IP
# Low|P
# Low|VR
# Medium|P
# Low|IP
# Low|R
# Low|R
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Progress saved: 39 files processed
# Building graph for Chopin | Waltz Op. 42 in A Major
# High|ID
# High|ID
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Low|R
# Low|R
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# VeryLow|M
# Low|ID
# VeryLow|M
# Low|ID
# VeryLow|M
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|P
# VeryLow|rest
# Medium|ID
# Medium|IP
# Low|P
# Low|R
# Medium|R
# Low|R
# Low|R
# Low|R
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|M
# Medium|P
# Low|P
# Low|P
# High|ID
# VeryLow|M
# VeryLow|M
# VeryLow|d
# VeryLow|M
# Low|P
# Low|P
# VeryLow|M
# VeryLow|M
# VeryLow|d
# VeryLow|M
# VeryLow|d
# VeryLow|M
# Low|R
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Progress saved: 39 files processed
# Building graph for Mozart | Minuet in G Major
# Error building graph for: Mozart | Minuet in G Major. Skipping file
# Traceback (most recent call last):
#   File "C:\.School\Thesisv3\thesisv3\classism.py", line 291, in build_graphs
#     graph = construct_graph(self.k, distance_matrix, self.segment_dict[file], force_connectivity=self.force_connectivity)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\.School\Thesisv3\thesisv3\building\building.py", line 102, in construct_graph
#     knn = kneighbors_graph(
#           ^^^^^^^^^^^^^^^^^
#   File "C:\.School\Thesisv3\.venv\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\.School\Thesisv3\.venv\Lib\site-packages\sklearn\neighbors\_graph.py", line 148, in kneighbors_graph
#     return X.kneighbors_graph(X=query, n_neighbors=n_neighbors, mode=mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\.School\Thesisv3\.venv\Lib\site-packages\sklearn\neighbors\_base.py", line 1012, in kneighbors_graph
#     A_data, A_ind = self.kneighbors(X, n_neighbors, return_distance=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\.School\Thesisv3\.venv\Lib\site-packages\sklearn\neighbors\_base.py", line 834, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors < n_samples_fit, but n_neighbors = 10, n_samples_fit = 10, n_samples = 10
#
# Building graph for Mozart | Piano Sonata No. 10 in C Major, K. 330 (1st movement)
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|R
# VeryLow|R
# Low|P
# Low|P
# Low|P
# VeryLow|ID
# Medium|P
# Low|P
# Low|P
# Medium|D
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# Medium|P
# Low|P
# Low|ID
# Low|ID
# Low|ID
# Low|R
# Low|P
# Low|ID
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Medium|P
# VeryLow|M
# High|D
# VeryLow|M
# Low|P
# Medium|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|IP
# Low|P
# VeryLow|R
# VeryLow|M
# VeryLow|M
# Progress saved: 39 files processed
# Building graph for Mozart | Piano Sonata No. 11 in A Major, K. 331 'Rondo Alla Turca'
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# Low|ID
# Medium|P
# Low|P
# High|P
# High|P
# High|P
# Medium|P
# Medium|P
# Low|VR
# High|P
# High|ID
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# High|P
# Low|P
# VeryLow|R
# VeryLow|R
# Low|R
# VeryLow|P
# Medium|ID
# Low|R
# VeryLow|P
# High|P
# Low|ID
# Low|P
# High|ID
# Low|ID
# VeryLow|P
# High|P
# Low|ID
# Progress saved: 39 files processed
# Building graph for Satie | Gnossienne No. 1
# Low|P
# Low|P
# VeryLow|IP
# Low|P
# Low|P
# Low|IP
# High|P
# Low|P
# Medium|ID
# High|P
# Low|P
# Medium|ID
# High|P
# Medium|P
# High|P
# Medium|ID
# Low|P
# High|ID
# Low|P
# Medium|ID
# High|P
# Low|P
# Medium|ID
# High|P
# Medium|P
# High|P
# Medium|ID
# Progress saved: 39 files processed
# Building graph for Satie | Gnossienne No. 2
# Low|ID
# High|ID
# VeryLow|rest
# High|ID
# VeryLow|rest
# High|P
# High|D
# VeryLow|P
# High|P
# Medium|D
# VeryLow|rest
# Medium|P
# High|D
# VeryLow|rest
# Medium|P
# High|D
# VeryLow|rest
# High|P
# High|D
# VeryLow|P
# Medium|D
# High|ID
# VeryLow|rest
# Progress saved: 39 files processed
# Building graph for Satie | Gnossienne No. 3
# Low|IP
# Low|P
# Low|IP
# Medium|P
# Low|P
# Low|IP
# Low|IP
# Low|P
# Medium|P
# VeryLow|IP
# High|P
# VeryLow|P
# Medium|R
# Low|IP
# Low|IP
# Progress saved: 39 files processed
# Building graph for Satie | Gnossienne No. 4
# VeryLow|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|P
# VeryLow|P
# Low|ID
# Low|P
# VeryLow|rest
# VeryLow|rest
# Progress saved: 39 files processed
# Building graph for Ysaÿe | Violin Sonata No. 1 in G Minor
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# VeryLow|VR
# VeryLow|rest
# VeryLow|P
# VeryLow|M
# VeryLow|M
# VeryLow|P
# VeryLow|M
# VeryLow|rest
# Low|R
# VeryLow|rest
# Low|IR
# Low|IR
# Low|P
# High|ID
# High|IP
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|M
# Low|P
# High|P
# VeryLow|M
# Low|P
# VeryLow|P
# VeryLow|M
# VeryLow|M
# VeryLow|d
# VeryLow|rest
# VeryLow|M
# VeryLow|R
# VeryLow|M
# Low|IR
# VeryLow|VP
# Low|IR
# Low|VP
# Low|IR
# Low|VP
# Low|P
# Low|IR
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# VeryLow|P
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|IR
# VeryLow|M
# VeryLow|M
# VeryLow|P
# VeryLow|rest
# Low|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|VP
# Low|R
# Low|IR
# VeryLow|rest
# Medium|R
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# VeryLow|IP
# Low|P
# Low|IR
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|M
# Low|P
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|ID
# Medium|P
# High|ID
# High|ID
# High|P
# Medium|ID
# VeryLow|P
# Low|P
# Low|R
# Low|R
# VeryLow|P
# Low|R
# Low|P
# Low|P
# Low|R
# Low|R
# Low|R
# Low|P
# Low|P
# Low|R
# Medium|P
# VeryLow|rest
# VeryLow|rest
# Low|P
# VeryLow|P
# VeryLow|R
# Low|ID
# VeryLow|M
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|R
# Low|P
# Medium|P
# Low|P
# VeryLow|R
# Low|P
# VeryLow|rest
# VeryLow|M
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|IP
# VeryLow|M
# VeryLow|D
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|ID
# VeryLow|R
# Low|ID
# Low|ID
# VeryLow|ID
# Low|P
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|P
# Low|P
# VeryLow|P
# Medium|P
# VeryLow|P
# Medium|P
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|M
# VeryLow|R
# Low|P
# Low|P
# Low|R
# Medium|R
# Medium|R
# Medium|R
# Low|P
# Low|ID
# Low|ID
# Medium|ID
# Low|ID
# VeryLow|rest
# VeryLow|M
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|IP
# VeryLow|M
# VeryLow|D
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|ID
# VeryLow|ID
# Low|P
# Low|P
# VeryLow|M
# VeryLow|R
# Low|R
# Low|R
# Low|IR
# Low|P
# Low|R
# Low|R
# Low|R
# Low|ID
# Low|R
# Low|P
# Low|IR
# Low|IR
# Low|R
# Medium|R
# Low|R
# Low|P
# Medium|R
# Low|P
# Low|R
# Low|P
# Low|ID
# Low|R
# Low|R
# VeryLow|rest
# Medium|P
# Medium|ID
# Low|ID
# Low|R
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|P
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|P
# VeryLow|R
# Low|R
# Low|R
# VeryLow|R
# Progress saved: 39 files processed
# Building graph for Ysaÿe | Violin Sonata No. 2 in A Minor
# Low|ID
# Low|R
# VeryLow|R
# Low|P
# Low|R
# VeryLow|R
# Low|P
# Low|R
# Medium|VR
# Medium|P
# Low|R
# Low|R
# Low|P
# Low|ID
# VeryLow|M
# Low|R
# Low|R
# VeryLow|P
# VeryLow|R
# VeryLow|R
# Low|P
# Medium|R
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|ID
# Low|R
# VeryLow|ID
# VeryLow|rest
# Low|R
# Low|R
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|R
# VeryLow|P
# Medium|P
# Low|P
# High|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# High|IP
# Medium|P
# Low|R
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|rest
# VeryLow|rest
# VeryLow|M
# VeryLow|rest
# Medium|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|P
# High|P
# Low|VR
# Low|P
# Low|P
# VeryLow|IR
# Low|P
# Low|R
# Low|P
# Medium|ID
# Low|P
# VeryLow|rest
# Low|P
# High|ID
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Medium|P
# Low|P
# Low|VR
# Low|ID
# Low|ID
# Low|P
# Low|R
# Medium|P
# Low|R
# Low|ID
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Medium|P
# Medium|P
# Low|VR
# Low|P
# Low|R
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|M
# VeryLow|P
# VeryLow|M
# Low|P
# VeryLow|d
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# Medium|R
# VeryLow|rest
# Low|R
# Low|P
# VeryLow|P
# VeryLow|IP
# VeryLow|R
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# Low|IP
# VeryLow|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# VeryLow|rest
# Low|R
# Low|R
# Low|R
# Low|R
# Low|IR
# VeryLow|P
# VeryLow|M
# Low|R
# VeryLow|rest
# VeryLow|P
# VeryLow|rest
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Low|ID
# Low|P
# Low|VR
# Low|R
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|IP
# Low|D
# Low|D
# Low|P
# Low|ID
# Low|P
# VeryLow|P
# VeryLow|rest
# VeryLow|IP
# VeryLow|P
# Low|R
# Low|D
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|M
# VeryLow|P
# VeryLow|IP
# VeryLow|R
# VeryLow|R
# VeryLow|rest
# VeryLow|P
# VeryLow|R
# VeryLow|IP
# Low|ID
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# VeryLow|rest
# Progress saved: 39 files processed
# Building graph for Ysaÿe | Violin Sonata No. 3 in D Minor
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Low|P
# Low|R
# VeryLow|M
# VeryLow|IR
# Low|P
# VeryLow|M
# VeryLow|M
# Low|R
# VeryLow|M
# Low|R
# Low|IP
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|R
# Low|R
# Low|ID
# Low|R
# Low|R
# VeryLow|ID
# Low|P
# VeryLow|R
# VeryLow|M
# VeryLow|M
# Low|P
# Low|R
# Low|VR
# Medium|P
# Medium|IP
# Medium|IP
# Medium|P
# Medium|IP
# Medium|P
# Medium|P
# Medium|P
# Medium|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|ID
# Low|ID
# Low|ID
# Low|IP
# Low|ID
# Medium|ID
# Medium|P
# High|ID
# Low|P
# High|ID
# Low|ID
# Low|P
# High|ID
# Low|ID
# High|ID
# High|ID
# Low|ID
# Medium|ID
# Medium|ID
# Low|R
# Low|R
# Low|ID
# Medium|ID
# Medium|P
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# VeryLow|rest
# Low|R
# VeryLow|M
# Medium|IP
# Low|P
# VeryLow|P
# VeryLow|R
# Low|R
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# Low|IR
# High|IP
# Medium|P
# High|P
# VeryLow|P
# VeryLow|rest
# VeryLow|R
# VeryLow|M
# Low|IP
# Low|R
# Low|IP
# Medium|R
# Medium|IP
# Medium|P
# Low|IP
# VeryLow|VR
# VeryLow|IR
# Low|P
# Low|R
# Low|R
# VeryLow|ID
# Low|ID
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|D
# VeryLow|rest
# VeryLow|D
# VeryLow|rest
# Low|R
# VeryLow|rest
# VeryLow|rest
# VeryLow|R
# Progress saved: 39 files processed
# Building graph for Ysaÿe | Violin Sonata No. 4 in E Minor
# Low|P
# Low|P
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|P
# VeryLow|R
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|R
# VeryLow|P
# Low|P
# Medium|P
# Low|P
# VeryLow|P
# VeryLow|P
# Low|ID
# Low|P
# Low|P
# Low|P
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Medium|P
# VeryLow|P
# Low|P
# VeryLow|IR
# VeryLow|rest
# Low|P
# VeryLow|P
# Low|VR
# VeryLow|d
# Low|P
# High|P
# Low|IP
# VeryLow|rest
# Low|IP
# Low|P
# Low|P
# Low|P
# VeryLow|R
# Medium|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|P
# VeryLow|R
# VeryLow|M
# Low|P
# Low|P
# VeryLow|M
# Low|P
# VeryLow|P
# Low|R
# VeryLow|P
# Low|R
# VeryLow|rest
# VeryLow|VR
# VeryLow|rest
# VeryLow|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|M
# Low|P
# VeryLow|rest
# VeryLow|rest
# Low|P
# VeryLow|M
# VeryLow|rest
# Low|P
# VeryLow|M
# VeryLow|rest
# Low|P
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|IR
# VeryLow|VR
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# VeryLow|rest
# Low|P
# VeryLow|d
# VeryLow|M
# VeryLow|IR
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|d
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Low|P
# Medium|P
# Medium|P
# Low|R
# Low|P
# Low|R
# Low|P
# Low|P
# Low|IR
# VeryLow|VR
# Low|R
# VeryLow|R
# Low|R
# VeryLow|R
# Low|R
# VeryLow|R
# Low|VR
# Low|R
# Low|R
# Low|R
# VeryLow|rest
# VeryLow|P
# Low|P
# Low|P
# VeryLow|P
# Medium|P
# Low|P
# Medium|P
# VeryLow|d
# VeryLow|M
# Low|R
# VeryLow|M
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# Low|P
# Medium|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|R
# Medium|P
# Low|P
# Medium|P
# Low|P
# Low|ID
# Low|P
# Low|P
# Low|R
# VeryLow|R
# Progress saved: 39 files processed
# Building graph for Ysaÿe | Violin Sonata No. 5 in G Major
# VeryLow|ID
# VeryLow|M
# VeryLow|D
# VeryLow|M
# VeryLow|M
# VeryLow|rest
# VeryLow|R
# Low|R
# Low|P
# Low|P
# VeryLow|IR
# VeryLow|IR
# Low|P
# Low|IP
# VeryLow|M
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# Low|P
# VeryLow|P
# VeryLow|P
# Low|ID
# VeryLow|P
# Low|ID
# Low|P
# VeryLow|R
# VeryLow|d
# VeryLow|M
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Medium|P
# VeryLow|P
# VeryLow|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# Low|P
# Low|P
# VeryLow|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|IR
# VeryLow|P
# VeryLow|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# Low|R
# Low|R
# Low|IR
# Low|R
# Low|IR
# Low|R
# Low|IR
# Low|R
# VeryLow|M
# VeryLow|M
# VeryLow|IR
# VeryLow|rest
# VeryLow|rest
# Low|VR
# VeryLow|ID
# VeryLow|M
# VeryLow|rest
# VeryLow|M
# VeryLow|rest
# VeryLow|d
# VeryLow|rest
# Low|P
# VeryLow|P
# Medium|P
# VeryLow|M
# VeryLow|R
# VeryLow|M
# VeryLow|R
# VeryLow|rest
# VeryLow|M
# VeryLow|M
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# VeryLow|M
# VeryLow|IR
# Low|R
# VeryLow|M
# VeryLow|rest
# Low|P
# VeryLow|d
# VeryLow|ID
# Low|R
# Low|P
# Low|P
# Low|VR
# Low|R
# VeryLow|rest
# Low|P
# Low|P
# VeryLow|ID
# VeryLow|rest
# VeryLow|M
# VeryLow|P
# VeryLow|ID
# Low|ID
# Low|ID
# Low|ID
# Low|ID
# VeryLow|M
# VeryLow|rest
# Medium|P
# Low|ID
# Low|R
# Low|P
# Medium|P
# Medium|P
# Medium|P
# Low|IP
# VeryLow|rest
# VeryLow|P
# VeryLow|rest
# VeryLow|P
# Low|ID
# VeryLow|rest
# Low|P
# VeryLow|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# Low|R
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# VeryLow|P
# Low|R
# Low|R
# Medium|R
# Low|R
# Low|R
# Medium|P
# Low|R
# Low|ID
# Medium|P
# Low|P
# Low|P
# Low|P
# VeryLow|IP
# VeryLow|rest
# VeryLow|M
# Low|R
# VeryLow|P
# Low|P
# Low|P
# Medium|P
# VeryLow|R
# Low|P
# Medium|P
# Medium|P
# Medium|P
# High|P
# Medium|P
# Medium|P
# Low|P
# Low|R
# Low|D
# Low|D
# Medium|D
# Low|D
# Medium|D
# Low|D
# Low|R
# Low|P
# High|P
# Low|P
# Low|R
# Low|R
# Low|P
# Medium|P
# High|P
# VeryLow|M
# Low|P
# Low|P
# VeryLow|rest
# Progress saved: 39 files processed
# Building graph for Ysaÿe | Violin Sonata No. 6 in E Major
# VeryLow|rest
# VeryLow|rest
# VeryLow|rest
# Medium|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|ID
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# VeryLow|rest
# VeryLow|P
# Low|P
# Low|R
# Low|P
# Low|P
# VeryLow|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|P
# Medium|P
# Medium|IP
# VeryLow|M
# VeryLow|rest
# Low|R
# Low|R
# VeryLow|R
# VeryLow|R
# VeryLow|R
# Low|R
# Low|R
# Low|P
# Medium|P
# Low|P
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# Low|P
# VeryLow|rest
# Low|P
# Low|IR
# Low|R
# Low|R
# Low|IP
# Low|R
# VeryLow|R
# Low|R
# Low|P
# Low|IP
# Low|R
# VeryLow|P
# Low|P
# Low|P
# Low|VR
# Low|P
# Low|R
# Low|R
# Low|R
# Low|R
# Low|IP
# VeryLow|VR
# VeryLow|rest
# Low|R
# Low|ID
# Medium|IP
# Medium|ID
# Low|ID
# Low|P
# Low|R
# Low|R
# Low|P
# Low|P
# High|ID
# Low|P
# Low|P
# VeryLow|IR
# Low|R
# Medium|P
# Low|R
# High|P
# Low|P
# Low|ID
# Low|P
# Low|R
# Medium|P
# Low|P
# Low|P
# VeryLow|M
# High|P
# Medium|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|P
# Low|R
# Low|P
# Low|P
# Low|P
# Low|P
# Low|IP
# Low|R
# Low|R
# Low|R
# Low|R
# VeryLow|R
# Low|R
# Low|R
# Low|P
# Low|IR
# Low|P
# Low|P
# VeryLow|P
# VeryLow|P
# VeryLow|P
# Low|P
# Low|R
# Low|R
# Low|R
# Medium|P
# Low|IP
# Low|IP
# Low|R
# Low|ID
# Low|P
# Low|ID
# Low|ID
# Low|P
# Low|P
# Progress saved: 39 files processed
# Completed building graphs for 38 files
# Completed processing for k=10
# ----------------------------------------

# %%
from thesisv3.validation.tuners import compare_kernels

# %%
batcher = GraphBatcher(output_dir="./Output/expectancy_v1", force_connectivity=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 batcher = GraphBatcher(output_dir="./Output/expectancy_v1", force_connectivity=True)
#
# NameError: name 'GraphBatcher' is not defined

# %%
batcher.graphs[0]

# %%
# Print nodes with attributes
print("Nodes:")
for node, attrs in batcher.graphs[0].nodes(data=True):
    print(f"  Node {node}: {attrs}")

# Print edges with attributes
print("\nEdges:")
for u, v, attrs in batcher.graphs[0].edges(data=True):
    print(f"  Edge ({u}, {v}): {attrs}")
# Out:
# Nodes:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Print nodes with attributes
#       2 print("Nodes:")
# ----> 3 for node, attrs in batcher.graphs[0].nodes(data=True):
#       4     print(f"  Node {node}: {attrs}")
#       6 # Print edges with attributes
#
# NameError: name 'batcher' is not defined

# %%
results2 = compare_kernels(batcher_dir="./Output/batcher_output_2", output_dir="./Output/tuner_output_22", min_k=2, max_k=10)
# Out:
# ============================================================
# Testing kernel: WeisfeilerLehman
# ============================================================
#
# Loaded previous progress: 39 files already processed, 0 k values already calculated
# Calculating graph statistics at k = 2
# Loading pre-constructed graphs for k=2
# Processing within-piece similarities:  21%|██        | 8/39 [00:00<00:00, 78.81it/s]
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Processing within-piece similarities: 100%|██████████| 39/39 [00:00<00:00, 162.48it/s]
# Processing between-piece similarities: 100%|██████████| 1482/1482 [00:04<00:00, 346.13it/s]
# Progress saved: 39 files processed, 1 k values calculated
# Calculating graph statistics at k = 3
# Reusing existing graphs with label: None
# Processing within-piece similarities:  92%|█████████▏| 36/39 [00:00<00:00, 193.74it/s]
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Processing within-piece similarities: 100%|██████████| 39/39 [00:00<00:00, 166.64it/s]
# Processing between-piece similarities: 100%|██████████| 1482/1482 [00:04<00:00, 315.68it/s]
# Progress saved: 39 files processed, 2 k values calculated
# Calculating graph statistics at k = 4
# Reusing existing graphs with label: None
# Processing within-piece similarities:  18%|█▊        | 7/39 [00:00<00:00, 69.08it/s]
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Processing within-piece similarities: 100%|██████████| 39/39 [00:00<00:00, 157.03it/s]
# Processing between-piece similarities: 100%|██████████| 1482/1482 [00:04<00:00, 341.01it/s]
# Progress saved: 39 files processed, 3 k values calculated
# Calculating graph statistics at k = 5
# Reusing existing graphs with label: None
# Processing within-piece similarities:  18%|█▊        | 7/39 [00:00<00:00, 67.62it/s]
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Processing within-piece similarities: 100%|██████████| 39/39 [00:00<00:00, 150.61it/s]
# Processing between-piece similarities: 100%|██████████| 1482/1482 [00:04<00:00, 338.12it/s]
# Progress saved: 39 files processed, 4 k values calculated
# Calculating graph statistics at k = 6
# Reusing existing graphs with label: None
# Processing within-piece similarities:  23%|██▎       | 9/39 [00:00<00:00, 87.49it/s]
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Processing within-piece similarities: 100%|██████████| 39/39 [00:00<00:00, 164.29it/s]
# Processing between-piece similarities: 100%|██████████| 1482/1482 [00:04<00:00, 347.85it/s]
# Progress saved: 39 files processed, 5 k values calculated
# Calculating graph statistics at k = 7
# Reusing existing graphs with label: None
# Processing within-piece similarities:  92%|█████████▏| 36/39 [00:00<00:00, 192.14it/s]
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Processing within-piece similarities: 100%|██████████| 39/39 [00:00<00:00, 163.85it/s]
# Processing between-piece similarities: 100%|██████████| 1482/1482 [00:04<00:00, 335.25it/s]
# Progress saved: 39 files processed, 6 k values calculated
# Calculating graph statistics at k = 8
# Reusing existing graphs with label: None
# Processing within-piece similarities:  21%|██        | 8/39 [00:00<00:00, 78.05it/s]
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Processing within-piece similarities: 100%|██████████| 39/39 [00:00<00:00, 161.47it/s]
# Processing between-piece similarities: 100%|██████████| 1482/1482 [00:04<00:00, 339.70it/s]
# Progress saved: 39 files processed, 7 k values calculated
# Calculating graph statistics at k = 9
# Reusing existing graphs with label: None
# Processing within-piece similarities:  18%|█▊        | 7/39 [00:00<00:00, 66.62it/s]
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Processing within-piece similarities: 100%|██████████| 39/39 [00:00<00:00, 148.51it/s]
# Processing between-piece similarities: 100%|██████████| 1482/1482 [00:04<00:00, 340.31it/s]
# C:\.School\Thesisv3\thesisv3\validation\tuners.py:367: UserWarning: Glyph 8209 (\N{NON-BREAKING HYPHEN}) missing from font(s) Arial.
#   plt.tight_layout()
# Progress saved: 39 files processed, 8 k values calculated
# C:\.School\Thesisv3\thesisv3\validation\tuners.py:368: UserWarning: Glyph 8209 (\N{NON-BREAKING HYPHEN}) missing from font(s) Arial.
#   plt.savefig(os.path.join(output_dir, 'summary', 'kernel_comparison_raw_vs_adj.png'))
# C:\.School\Thesisv3\thesisv3\validation\tuners.py:372: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\.School\Thesisv3\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8209 (\N{NON-BREAKING HYPHEN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
results = compare_kernels(batcher_dir="./Output/expectancy_v1", output_dir="./Output/tuner_output_2", min_k=2, max_k=10, label='expectancy')
# Out:
# ============================================================
# Testing kernel: WeisfeilerLehman
# ============================================================
#
# Loaded previous progress: 39 files already processed, 8 k values already calculated
# Using cached results for k = 2
# Using cached results for k = 3
# Using cached results for k = 4
# Using cached results for k = 5
# Using cached results for k = 6
# Using cached results for k = 7
# Using cached results for k = 8
# Using cached results for k = 9
#
# ============================================================
# Testing kernel: ShortestPath
# ============================================================
#
# Loaded previous progress: 39 files already processed, 0 k values already calculated
# Calculating graph statistics at k = 2
# Constructing graphs with custom label: expectancy
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# The k‑NN graph is disjoint. Ensuring connectivity…
# inv_weight
# Bach | Cello Suite No. 1 in G Major
# Bach | Cello Suite No. 2 in D Minor
# Bach | Cello Suite No. 3 in C Major
# Bach | Cello Suite No. 4 in E-flat Major
# Bach | Cello Suite No. 5 in C Minor
# Bach | Cello Suite No. 6 in D Major
# Chopin | Étude Op. 10 No. 1 'Waterfall'
# Chopin | Étude Op. 10 No. 2 'Chromatic'
# Chopin | Étude Op. 10 No. 4 'Torrent'
# Chopin | Étude Op. 10 No. 5 'Black Keys'
# Chopin | Étude Op. 10 No. 6 'Lament'
# Chopin | Étude Op. 10 No. 7 'Toccata'
# Chopin | Étude Op. 10 No. 8 'Sunshine'
# Chopin | Étude Op. 10 No. 9
# Chopin | Étude Op. 10 No. 10
# Chopin | Étude Op. 25 No. 2 'The Bees'
# Chopin | Étude Op. 25 No. 9 'Butterfly'
# Chopin | Étude Op. 25 No. 11 'Winter Wind'
# Chopin | Étude Op. 25 No. 12 'Ocean'
# Chopin | Waltz Op. 34 No. 1 in A-flat Major
# Chopin | Waltz Op. 34 No. 2 in A Minor
# Chopin | Waltz Op. 34 No. 3 in F Major
# Chopin | Waltz Op. 64 No. 1 'Minute Waltz'
# Chopin | Waltz Op. 64 No. 2 in C Minor
# Chopin | Waltz Op. 64 No. 3 in A-flat Major
# Chopin | Waltz Op. 42 in A Major
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Mozart | Piano Sonata No. 10 in C Major, K. 330 (1st movement)
# Mozart | Piano Sonata No. 11 in A Major, K. 331 'Rondo Alla Turca'
# Satie | Gnossienne No. 1
# Satie | Gnossienne No. 2
# Satie | Gnossienne No. 3
# Satie | Gnossienne No. 4
# Ysaÿe | Violin Sonata No. 1 in G Minor
# Ysaÿe | Violin Sonata No. 2 in A Minor
# Ysaÿe | Violin Sonata No. 3 in D Minor
# Ysaÿe | Violin Sonata No. 4 in E Minor
# Ysaÿe | Violin Sonata No. 5 in G Major
# Ysaÿe | Violin Sonata No. 6 in E Major
# Bach | Cello Suite No. 1 in G Major
# Bach | Cello Suite No. 2 in D Minor
# Bach | Cello Suite No. 3 in C Major
# Bach | Cello Suite No. 4 in E-flat Major
# Bach | Cello Suite No. 5 in C Minor
# Bach | Cello Suite No. 6 in D Major
# Chopin | Étude Op. 10 No. 1 'Waterfall'
# Chopin | Étude Op. 10 No. 2 'Chromatic'
# Chopin | Étude Op. 10 No. 4 'Torrent'
# Chopin | Étude Op. 10 No. 5 'Black Keys'
# Chopin | Étude Op. 10 No. 6 'Lament'
# Chopin | Étude Op. 10 No. 7 'Toccata'
# Chopin | Étude Op. 10 No. 8 'Sunshine'
# Chopin | Étude Op. 10 No. 9
# Chopin | Étude Op. 10 No. 10
# Chopin | Étude Op. 25 No. 2 'The Bees'
# Chopin | Étude Op. 25 No. 9 'Butterfly'
# Chopin | Étude Op. 25 No. 11 'Winter Wind'
# Chopin | Étude Op. 25 No. 12 'Ocean'
# Chopin | Waltz Op. 34 No. 1 in A-flat Major
# Chopin | Waltz Op. 34 No. 2 in A Minor
# Chopin | Waltz Op. 34 No. 3 in F Major
# Chopin | Waltz Op. 64 No. 1 'Minute Waltz'
# Chopin | Waltz Op. 64 No. 2 in C Minor
# Chopin | Waltz Op. 64 No. 3 in A-flat Major
# Chopin | Waltz Op. 42 in A Major
# Mozart | Minuet in G Major
# Mozart | Piano Sonata No. 10 in C Major, K. 330 (1st movement)
# Mozart | Piano Sonata No. 11 in A Major, K. 331 'Rondo Alla Turca'
# Satie | Gnossienne No. 1
# Satie | Gnossienne No. 2
# Satie | Gnossienne No. 3
# Satie | Gnossienne No. 4
# Ysaÿe | Violin Sonata No. 1 in G Minor
# Ysaÿe | Violin Sonata No. 2 in A Minor
# Ysaÿe | Violin Sonata No. 3 in D Minor
# Ysaÿe | Violin Sonata No. 4 in E Minor
# Ysaÿe | Violin Sonata No. 5 in G Major
# Ysaÿe | Violin Sonata No. 6 in E Major
# Progress saved: 39 files processed, 1 k values calculated
# Calculating graph statistics at k = 3
# Reusing existing graphs with label: expectancy
# inv_weight
# Bach | Cello Suite No. 1 in G Major
# Bach | Cello Suite No. 2 in D Minor
# Bach | Cello Suite No. 3 in C Major
# Bach | Cello Suite No. 4 in E-flat Major
# Bach | Cello Suite No. 5 in C Minor
# Bach | Cello Suite No. 6 in D Major
# Chopin | Étude Op. 10 No. 1 'Waterfall'
# Chopin | Étude Op. 10 No. 2 'Chromatic'
# Chopin | Étude Op. 10 No. 4 'Torrent'
# Chopin | Étude Op. 10 No. 5 'Black Keys'
# Chopin | Étude Op. 10 No. 6 'Lament'
# Chopin | Étude Op. 10 No. 7 'Toccata'
# Chopin | Étude Op. 10 No. 8 'Sunshine'
# Chopin | Étude Op. 10 No. 9
# Chopin | Étude Op. 10 No. 10
# Chopin | Étude Op. 25 No. 2 'The Bees'
# Chopin | Étude Op. 25 No. 9 'Butterfly'
# Chopin | Étude Op. 25 No. 11 'Winter Wind'
# Chopin | Étude Op. 25 No. 12 'Ocean'
# Chopin | Waltz Op. 34 No. 1 in A-flat Major
# Chopin | Waltz Op. 34 No. 2 in A Minor
# Chopin | Waltz Op. 34 No. 3 in F Major
# Chopin | Waltz Op. 64 No. 1 'Minute Waltz'
# Chopin | Waltz Op. 64 No. 2 in C Minor
# Chopin | Waltz Op. 64 No. 3 in A-flat Major
# Chopin | Waltz Op. 42 in A Major
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Mozart | Piano Sonata No. 10 in C Major, K. 330 (1st movement)
# Mozart | Piano Sonata No. 11 in A Major, K. 331 'Rondo Alla Turca'
# Satie | Gnossienne No. 1
# Satie | Gnossienne No. 2
# Satie | Gnossienne No. 3
# Satie | Gnossienne No. 4
# Ysaÿe | Violin Sonata No. 1 in G Minor
# Ysaÿe | Violin Sonata No. 2 in A Minor
# Ysaÿe | Violin Sonata No. 3 in D Minor
# Ysaÿe | Violin Sonata No. 4 in E Minor
# Ysaÿe | Violin Sonata No. 5 in G Major
# Ysaÿe | Violin Sonata No. 6 in E Major
# Bach | Cello Suite No. 1 in G Major
# Bach | Cello Suite No. 2 in D Minor
# Bach | Cello Suite No. 3 in C Major
# Bach | Cello Suite No. 4 in E-flat Major
# Bach | Cello Suite No. 5 in C Minor
# Bach | Cello Suite No. 6 in D Major
# Chopin | Étude Op. 10 No. 1 'Waterfall'
# Chopin | Étude Op. 10 No. 2 'Chromatic'
# Chopin | Étude Op. 10 No. 4 'Torrent'
# Chopin | Étude Op. 10 No. 5 'Black Keys'
# Chopin | Étude Op. 10 No. 6 'Lament'
# Chopin | Étude Op. 10 No. 7 'Toccata'
# Chopin | Étude Op. 10 No. 8 'Sunshine'
# Chopin | Étude Op. 10 No. 9
# Chopin | Étude Op. 10 No. 10
# Chopin | Étude Op. 25 No. 2 'The Bees'
# Chopin | Étude Op. 25 No. 9 'Butterfly'
# Chopin | Étude Op. 25 No. 11 'Winter Wind'
# Chopin | Étude Op. 25 No. 12 'Ocean'
# Chopin | Waltz Op. 34 No. 1 in A-flat Major
# Chopin | Waltz Op. 34 No. 2 in A Minor
# Chopin | Waltz Op. 34 No. 3 in F Major
# Chopin | Waltz Op. 64 No. 1 'Minute Waltz'
# Chopin | Waltz Op. 64 No. 2 in C Minor
# Chopin | Waltz Op. 64 No. 3 in A-flat Major
# Chopin | Waltz Op. 42 in A Major
# Mozart | Minuet in G Major
# Mozart | Piano Sonata No. 10 in C Major, K. 330 (1st movement)
# Mozart | Piano Sonata No. 11 in A Major, K. 331 'Rondo Alla Turca'
# Satie | Gnossienne No. 1
# Satie | Gnossienne No. 2
# Satie | Gnossienne No. 3
# Satie | Gnossienne No. 4
# Ysaÿe | Violin Sonata No. 1 in G Minor
# Ysaÿe | Violin Sonata No. 2 in A Minor
# Ysaÿe | Violin Sonata No. 3 in D Minor
# Ysaÿe | Violin Sonata No. 4 in E Minor
# Ysaÿe | Violin Sonata No. 5 in G Major
# Ysaÿe | Violin Sonata No. 6 in E Major
# Progress saved: 39 files processed, 2 k values calculated
# Calculating graph statistics at k = 4
# Reusing existing graphs with label: expectancy
# inv_weight
# Bach | Cello Suite No. 1 in G Major
# Bach | Cello Suite No. 2 in D Minor
# Bach | Cello Suite No. 3 in C Major
# Bach | Cello Suite No. 4 in E-flat Major
# Bach | Cello Suite No. 5 in C Minor
# Bach | Cello Suite No. 6 in D Major
# Chopin | Étude Op. 10 No. 1 'Waterfall'
# Chopin | Étude Op. 10 No. 2 'Chromatic'
# Chopin | Étude Op. 10 No. 4 'Torrent'
# Chopin | Étude Op. 10 No. 5 'Black Keys'
# Chopin | Étude Op. 10 No. 6 'Lament'
# Chopin | Étude Op. 10 No. 7 'Toccata'
# Chopin | Étude Op. 10 No. 8 'Sunshine'
# Chopin | Étude Op. 10 No. 9
# Chopin | Étude Op. 10 No. 10
# Chopin | Étude Op. 25 No. 2 'The Bees'
# Chopin | Étude Op. 25 No. 9 'Butterfly'
# Chopin | Étude Op. 25 No. 11 'Winter Wind'
# Chopin | Étude Op. 25 No. 12 'Ocean'
# Chopin | Waltz Op. 34 No. 1 in A-flat Major
# Chopin | Waltz Op. 34 No. 2 in A Minor
# Chopin | Waltz Op. 34 No. 3 in F Major
# Chopin | Waltz Op. 64 No. 1 'Minute Waltz'
# Chopin | Waltz Op. 64 No. 2 in C Minor
# Chopin | Waltz Op. 64 No. 3 in A-flat Major
# Chopin | Waltz Op. 42 in A Major
# Skipping Mozart | Minuet in G Major: insufficient segments (10)
# Mozart | Piano Sonata No. 10 in C Major, K. 330 (1st movement)
# Mozart | Piano Sonata No. 11 in A Major, K. 331 'Rondo Alla Turca'
# Satie | Gnossienne No. 1
# Satie | Gnossienne No. 2
# Satie | Gnossienne No. 3
# Satie | Gnossienne No. 4
# Ysaÿe | Violin Sonata No. 1 in G Minor
# Ysaÿe | Violin Sonata No. 2 in A Minor
# Ysaÿe | Violin Sonata No. 3 in D Minor
# Ysaÿe | Violin Sonata No. 4 in E Minor
# Ysaÿe | Violin Sonata No. 5 in G Major
# Ysaÿe | Violin Sonata No. 6 in E Major
# Bach | Cello Suite No. 1 in G Major
# Bach | Cello Suite No. 2 in D Minor
# Bach | Cello Suite No. 3 in C Major
# Bach | Cello Suite No. 4 in E-flat Major
# Bach | Cello Suite No. 5 in C Minor
# Bach | Cello Suite No. 6 in D Major
# Chopin | Étude Op. 10 No. 1 'Waterfall'
# Chopin | Étude Op. 10 No. 2 'Chromatic'
# Chopin | Étude Op. 10 No. 4 'Torrent'
# Chopin | Étude Op. 10 No. 5 'Black Keys'
# Chopin | Étude Op. 10 No. 6 'Lament'
# Chopin | Étude Op. 10 No. 7 'Toccata'
# Chopin | Étude Op. 10 No. 8 'Sunshine'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 results = compare_kernels(batcher_dir="./Output/expectancy_v1", output_dir="./Output/tuner_output_2", min_k=2, max_k=10, label='expectancy')
#
# File C:\.School\Thesisv3\thesisv3\validation\tuners.py:332, in compare_kernels(batcher_dir, output_dir, label, min_k, max_k, k_step)
#     321 print(f"\n{'=' * 60}\nTesting kernel: {name}\n{'=' * 60}\n")
#     323 tuner = KNNGraphTuner(
#     324     graph_kernel=kernel,
#     325     batcher_dir=batcher_dir,
#    (...)
#     329     output_dir=os.path.join(output_dir, name.lower().replace(" ", "_"))
#     330 )
# --> 332 df = tuner.calculate_graph_statistics(label=label)
#     333 results[name] = df  # keep for later
#     335 # ── Plot FDR‑corrected p‑values for this kernel ──────────────────────
#
# File C:\.School\Thesisv3\thesisv3\validation\tuners.py:153, in KNNGraphTuner.calculate_graph_statistics(self, label)
#     151 idx = len(graph_statistics)
#     152 print(f"Calculating graph statistics at k = {k}")
# --> 153 within, between = self._kernel_based_similarity(k, label)
#     155 # Normality tests
#     156 _, p_norm_within = shapiro(within)
#
# File C:\.School\Thesisv3\thesisv3\validation\tuners.py:115, in KNNGraphTuner._kernel_based_similarity(self, k, label)
#     112     print(f"Reusing existing graphs with label: {getattr(self, 'label_used', None)}")
#     114 # Get a single DataFrame containing BOTH within‑ and between‑piece sims
# --> 115 pair_df = compare_within_and_between_pieces(self.distmat_dict, self.graph_dict, self.graph_kernel, minimum_segments=11)
#     117 # Separate the two cases
#     118 within_mask = pair_df['Piece_1'] == pair_df['Piece_2']
#
# File C:\.School\Thesisv3\thesisv3\validation\comparison.py:131, in compare_within_and_between_pieces(pieces_dist_mat, pieces_graph_dict, kernel, minimum_segments)
#     124     # Compute WL kernel similarity between graph_1 of piece1 and graph_1 of piece2
#     125     # grakel_graphs = [nx_to_grakel(G) for G in [full_graph1, full_graph2]]
#     126     grakel_graphs = graph_from_networkx(
#     127         [full_graph1, full_graph2],
#     128         node_labels_tag="label",
#     129         edge_weight_tag=edge_weight_tag
#     130     )
# --> 131     similarity_between = compare_graphs_kernel(list(grakel_graphs), kernel)[0, 1]
#     132     between_piece_scores.append({
#     133         'Piece_1': piece_1,
#     134         'Piece_2': piece_2,
#     135         'Between_Similarity': similarity_between
#     136     })
#     137 print(piece_names[i])
#
# File C:\.School\Thesisv3\thesisv3\validation\comparison.py:68, in compare_graphs_kernel(grakel_graphs, graph_kernel)
#      66     similarity_matrix = LovaszTheta(normalize=True, max_dim=max_dim).fit_transform(grakel_graphs)
#      67     return similarity_matrix
# ---> 68 similarity_matrix = kernel.fit_transform(grakel_graphs)
#      69 return similarity_matrix
#
# File C:\.School\Thesisv3\.venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File C:\.School\Thesisv3\.venv\Lib\site-packages\grakel\kernels\shortest_path.py:397, in ShortestPath.fit_transform(self, X, y)
#     394 self.fit(X)
#     396 # calculate feature matrices.
# --> 397 phi_x = np.zeros(shape=(self._nx, len(self._enum)))
#     399 for i in self.X.keys():
#     400     for j in self.X[i].keys():
#
# KeyboardInterrupt:

# %%
type(results['WeisfeilerLehman'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from io import StringIO

# Convert to DataFrame
df = results['WeisfeilerLehman'].copy()

# Create visualizations with tqdm progress tracking
print("Generating visualizations...")
figs = []

with tqdm(total=3, desc="Creating plots") as pbar:
    # Plot 1: P-values vs k
    fig1 = plt.figure(figsize=(10, 6))
    plt.plot(df['k'], df['parametric_p_adj'], 'o-', label='Parametric p (FDR)', lw=1.8)
    plt.plot(df['k'], df['non_parametric_p_adj'], 's--', label='Non-param p (FDR)', lw=1.8)
    plt.axhline(0.05, ls=':', color='red', label='α = 0.05')
    plt.yscale('log')  # Use log scale for better visibility of small p-values
    plt.xlabel('k (neighbours)')
    plt.ylabel('FDR-corrected p-value (log scale)')
    plt.title('FDR-corrected p-values vs k')
    plt.grid(ls='--', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    figs.append(fig1)
    pbar.update(1)
    
    # Plot 2: Within vs Between distances
    fig2 = plt.figure(figsize=(10, 6))
    plt.plot(df['k'], df['average_within'], 'o-', label='Within-group distance', lw=1.8)
    plt.plot(df['k'], df['average_between'], 's--', label='Between-group distance', lw=1.8)
    plt.xlabel('k (neighbours)')
    plt.ylabel('Average distance')
    plt.title('Within vs Between group distances')
    plt.grid(ls='--', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    figs.append(fig2)
    pbar.update(1)
    
    # Plot 3: Effect size metrics
    fig3 = plt.figure(figsize=(10, 6))
    plt.plot(df['k'], df['cohens_d'], 'o-', label="Cohen's d", lw=1.8)
    plt.plot(df['k'], df['auc'], 's--', label='AUC', lw=1.8)
    plt.xlabel('k (neighbours)')
    plt.ylabel('Effect size')
    plt.title('Effect size metrics vs k')
    plt.grid(ls='--', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    figs.append(fig3)
    pbar.update(1)

# %%
from thesisv3.validation.clustering import GraphKMeans
batcher = GraphBatcher(k=8)
g_kmeans = GraphKMeans(batcher.processed_files, batcher.graphs, k=5)
clustered, labels = g_kmeans.get_labels()
# clustered
g_kmeans.visualize_interactive(display_file_name=False)

# %%
clustered

# %%
g_kmeans.visualize()

# %%
# import networkx as nx
# 
# # Assuming G is your graph
# degrees = [deg for node, deg in G.degree()]
# print("Sample node degrees:", degrees[:10])
# print("Most common degree:", max(set(degrees), key=degrees.count))

# %%
batcher.segment_dict.keys()

# %%
# Create a consolidated list of all segments
all_segments = []
segment_metadata = []  # To track which composer and piece each segment belongs to

for composer, df_list in batcher.segment_dict.items():
    for piece_idx, df in enumerate(df_list):
        all_segments.append(df)
        segment_metadata.append({
            'composer': composer,
            'piece_idx': piece_idx
        })

# %%
from thesisv3.preprocessing.preprocessing import segments_to_distance_matrix

# %% [markdown]
# # GRAPH

# %%
from thesisv3.building.building import distance_matrices_to_knn_graphs
from thesisv3.analysis.analysis import kernighan_lin_partition, spectral_partition, get_sub_distance_matrix, dist_mat_to_graph

# %%
batcher = GraphBatcher(k=8)

# %%
type(batcher.segment_dict[list(batcher.segment_dict.keys())[0]][0])

# %%
import pandas as pd

# Assuming your dictionary is called 'data_dict'
all_expectancy_values = []

# Iterate through all values (lists of dataframes) in the dictionary
for df_list in batcher.segment_dict.values():
    # Iterate through each dataframe in the list
    for df in df_list:
        # Extract the 'expectancy' column and add its values to our list
        all_expectancy_values.extend(df['expectancy'].tolist())

# Convert to a pandas Series for easy statistical analysis
expectancy_series = pd.Series(all_expectancy_values)

# Now you can get statistics
print(expectancy_series.describe())  # Gives count, mean, std, min, 25%, 50%, 75%, max

# Or individual statistics
mean = expectancy_series.mean()
median = expectancy_series.median()
std_dev = expectancy_series.std()

# %%
pieces = batcher.processed_files
for i, name in enumerate(pieces):
    print(f"{i}: {name}")

# %%
filename = pieces[38]
# Perform spectral partitioning
group1, group2 = spectral_partition(batcher.distmat_dict[filename])

# Extract sub-distance matrices
D_group1 = get_sub_distance_matrix(batcher.distmat_dict[filename], group1)
D_group2 = get_sub_distance_matrix(batcher.distmat_dict[filename], group2)

# %%
dm = {f'{filename}\nSpectral Partition 1\n': D_group1, f'{filename}\nSpectral Partition 2\n': D_group2}

# %%
distance_matrices_to_knn_graphs(6, dm, 69, 777)

# %%
filename = pieces[21]
# Perform spectral partitioning
group1, group2 = kernighan_lin_partition(batcher.distmat_dict[filename])

# Extract sub-distance matrices
D_group1 = get_sub_distance_matrix(batcher.distmat_dict[filename], group1)
D_group2 = get_sub_distance_matrix(batcher.distmat_dict[filename], group2)
dm = {f'{filename}\nKL Partition 1\n': D_group1, f'{filename}\nKL Partition 2\n': D_group2}
distance_matrices_to_knn_graphs(6, dm, 9, 1777)

# %%
main = {f"{filename}": batcher.distmat_dict[filename]}
distance_matrices_to_knn_graphs(6, main, 9, 1777)

# %%
batcher_distance_weight = GraphBatcher(k=8, output_dir="./Output/batcher_output_distance_graph")

# %%
distance_matrices_to_knn_graphs(
    k=6, 
    distance_matrices=batcher_distance_weight.distmat_dict, 
    segments=batcher_distance_weight.segment_dict,
    seed=9, 
    iterations=1777, 
    layout_type="spring",
    force_connectivity=True,
    save_figures=False
)

# %%
distance_matrices_to_knn_graphs(
    k=6, 
    distance_matrices=batcher.distmat_dict, 
    segments=batcher.segment_dict,
    seed=9, 
    iterations=1777, 
    layout_type="spring",
    force_connectivity=True,
    save_figures=True
)

# %%
distance_matrices_to_knn_graphs(
    k=8, 
    distance_matrices=batcher.distmat_dict, 
    segments=batcher.segment_dict,
    seed=9, 
    iterations=1777, 
    layout_type="spring",
    force_connectivity=True,
    save_figures=True
)

# %%
distance_matrices_to_knn_graphs(
    k=4, 
    distance_matrices=batcher.distmat_dict, 
    segments=batcher.segment_dict,
    seed=9, 
    iterations=1777, 
    layout_type="spring",
    force_connectivity=True,
    save_figures=True
)

# %%
|distance_matrices_to_knn_graphs(
    k=6, 
    distance_matrices=batcher.distmat_dict, 
    seed=9, 
    iterations=1777, 
    layout_type="spectral",
    force_connectivity=True,
    save_figures=False
)

# %%
distance_matrices_to_knn_graphs(
    k=6, 
    distance_matrices=batcher.distmat_dict, 
    seed=9, 
    iterations=1777, 
    layout_type="kamada",
    force_connectivity=True,
    save_figures=False
)

# %% [markdown]
# # Graph Comparisons

# %%
from thesisv3.validation.comparison import compare_graphs
from thesisv3.analysis.analysis import get_sub_distance_matrix, spectral_partition, dist_mat_to_graph, kernighan_lin_partition

# %%
graph1 = batcher.graph_dict['Chopin | Waltz Op. 64 No. 2 in C Minor']
graph2 = batcher.graph_dict['Chopin | Waltz Op. 64 No. 2 in C Minor']
compare_graphs([graph1, graph2])

# %%
dm1 = batcher.distmat_dict['Chopin | Waltz Op. 64 No. 2 in C Minor']
dm2 = batcher.distmat_dict['Chopin | Waltz Op. 64 No. 2 in C Minor']

# %%
group1, group2 = spectral_partition(dm1)

D_group1 = get_sub_distance_matrix(dm1, group1)
D_group2 = get_sub_distance_matrix(dm1, group2)

# Generate k-NN graphs for each partition
graph_1 = dist_mat_to_graph(6, D_group1)
graph_2 = dist_mat_to_graph(6, D_group2)
full_graph = dist_mat_to_graph(6, dm1)


# Compute WL kernel similarity for within-piece (same piece)
compare_graphs([graph_1, graph_2])[0, 1]

# %%
group1, group2 = kernighan_lin_partition(dm1)

D_group1 = get_sub_distance_matrix(dm1, group1)
D_group2 = get_sub_distance_matrix(dm1, group2)

# Generate k-NN graphs for each partition
graph_1 = dist_mat_to_graph(6, D_group1)
graph_2 = dist_mat_to_graph(6, D_group2)

# Compute WL kernel similarity for within-piece (same piece)
compare_graphs([graph_1, graph_2])[0, 1]

# %%
import numpy as np

# %% [markdown]
# ___
# # KL Graph

# %%
def kernighan_lin_partition3(graph_thing, dist_mat, seed=None):
    """
    Partition a set of nodes using the Kernighan-Lin algorithm based on a distance matrix.
    Returns two groups of node indices similar to the spectral_partition function.

    Parameters:
    -----------
    distance_matrix : np.ndarray
        Matrix of distances between nodes
    seed : int, optional
        Random seed for reproducibility

    Returns:
    --------
    tuple: (group_1, group_2)
        Two arrays of node indices representing the partition
    """
    import networkx as nx
    # Create a graph from the distance matrix
    graph = graph_thing.copy()

    for u, v in graph.edges():
        # graph[u][v]['weight'] = 1 / (dist_mat[u, v] + 1e-5)  # Add a small constant to avoid division by zero
        #
        # # log transformed
        # graph[u][v]['weight'] = 1 / (np.log1p(dist_mat[u, v] + 1e-5))
        #
        # # exponential decay
        # graph[u][v]['weight'] = np.exp(-dist_mat[u, v])

        # Gaussian/RBF Kernel
        sigma = np.median(dist_mat[dist_mat > 0])
        graph[u][v]['weight'] = np.exp(-dist_mat[u, v]**2 / (2 * sigma**2))

    # Set random seed
    rng = np.random.default_rng(seed)

    # Use Kernighan-Lin bisection
    part1, part2 = nx.algorithms.community.kernighan_lin_bisection(graph, weight="weight", seed=rng)


    # Return subgraphs corresponding to the partitions
    subgraph_1 = graph.subgraph(part1).copy()
    subgraph_2 = graph.subgraph(part2).copy()

    return subgraph_1, subgraph_2

# %%
graph_1, graph_2 = kernighan_lin_partition3(graph1, dm1)

# Compute WL kernel similarity for within-piece (same piece)
compare_graphs([graph_1, graph_2])[0, 1]

# %% [markdown]
# ___
# # Heatmap

# %%
from thesisv3.validation.comparison import compare_within_and_between_pieces
import grakel as gk

# %%
batcher = GraphBatcher(k=6)

# %%
x = compare_within_and_between_pieces(batcher.distmat_dict, batcher.distmat_dict, gk.WeisfeilerLehman(n_iter=5, normalize=True),)

# %%
df_filtered = x.copy()

# %%
df_filtered.loc[:, 'Between_Similarity'] = (df_filtered['Between_Similarity'] - df_filtered['Between_Similarity'].min()) / (df_filtered['Between_Similarity'].max() - df_filtered['Between_Similarity'].min())

# %%
x.describe()

# %%
df_filtered

# %%
from thesisv3.validation.clustering import GraphKMeans

g_kmeans = GraphKMeans(batcher.processed_files, batcher.graphs, k=6)
clustered, labels = g_kmeans.get_labels()
# clustered
g_kmeans.visualize_interactive(display_file_name=False)

# %%
g_kmeans.graphs

# %%
g_kmeans.visualize_interactive(display_file_name=False)

# %%
g_kmeans.visualize(display_file_name=True)

# %% [markdown]
# Heatmap

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_filtered is already defined
similarity_matrix_new = df_filtered.pivot_table(index='Piece_1', columns='Piece_2', values='Between_Similarity')

# Create mask for upper triangle (including diagonal if you want to hide it)
mask = np.triu(np.ones_like(similarity_matrix_new, dtype=bool))
# If you want to show the diagonal, uncomment the next line
# np.fill_diagonal(mask, False)

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(similarity_matrix_new, cmap="Blues", annot=False, cbar=True, fmt=".2f", vmin=0, mask=mask)

# Show the plot
plt.title("Heatmap of Between Pieces Similarity (Min-Max Normalized)")
plt.tight_layout()
plt.show()

# %%
similarity_matrix_new = df_filtered.pivot_table(index='Piece_1', columns='Piece_2', values='Between_Similarity')
similarity_matrix_new = similarity_matrix_new

mask = np.triu(np.ones_like(similarity_matrix_new, dtype=bool))
np.fill_diagonal(mask, False)

# Create a heatmap from the new data
plt.figure(figsize=(30, 25))
sns.heatmap(similarity_matrix_new.iloc[::-1], cmap="Blues", annot=True, cbar=True, fmt=".2f", vmin=0, mask=mask[::-1])

# Show the plot
plt.title("Heatmap of Between Pieces Similarity (Min-Max Normalized)")
plt.tight_layout()
plt.show()

# %%
similarity_matrix_new.to_csv("sim_mat.csv", index=True)

# %%
similarity_matrix_new = pd.read_csv("sim_mat.csv", index_col='Piece_1')

# %%
similarity_matrix_new

# %%
upper_triangle = similarity_matrix_new.where(np.triu(np.ones_like(similarity_matrix_new), k=1).astype(bool))
upper_triangle

# %%
# Reshape to get all values in a Series
similarities = upper_triangle.stack().reset_index()
similarities.columns = ['Piece_1', 'Piece_2', 'Similarity']

# %%
similarities

# %%
# Calculate median similarity
median_similarity = similarities['Similarity'].median()
print(f"Median Similarity: {median_similarity:.4f}")

# Get top 10 highest similarities
top10 = similarities.nlargest(10, 'Similarity')
print("\nTop 10 Highest Similarities:")
for i, (idx, row) in enumerate(top10.iterrows(), 1):
    print(f"{i}. {row['Piece_1']} - {row['Piece_2']}: {row['Similarity']:.4f}")

# Get bottom 10 lowest similarities
bottom10 = similarities.nsmallest(10, 'Similarity')
print("\nBottom 10 Lowest Similarities:")
for i, (idx, row) in enumerate(bottom10.iterrows(), 1):
    print(f"{i}. {row['Piece_1']} - {row['Piece_2']}: {row['Similarity']:.4f}")

# %%
upper_triangle = similarity_matrix_new.where(np.triu(np.ones_like(similarity_matrix_new), k=1).astype(bool))

# Reshape to get all values in a Series
similarities = upper_triangle.stack().reset_index()
similarities.columns = ['Piece_1', 'Piece_2', 'Similarity']

# Calculate median similarity
median_similarity = similarities['Similarity'].mean()
print(f"Median Similarity: {median_similarity:.4f}")

# Find the pair(s) closest to the median
similarities['Median_Diff'] = (similarities['Similarity'] - median_similarity).abs()
closest_to_median = similarities.nsmallest(10, 'Median_Diff')

print("\nPiece Pair(s) Closest to the Median Similarity:")
for i, row in closest_to_median.iterrows():
    print(f"{row['Piece_1']} - {row['Piece_2']}: {row['Similarity']:.4f}")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size and style
plt.figure(figsize=(10, 8))
sns.set_style("whitegrid")

# Load the CSV data
df = pd.read_csv('Output/sim_mat.csv')

# Function to determine piece type
def get_piece_type(piece_name):
    parts = piece_name.split('|')
    if len(parts) > 1:
        piece_part = parts[1].strip()

        # Special handling for Chopin's Études
        if 'Étude' in piece_part:
            if 'Op. 10' in piece_part:
                return "Chopin's Études Op. 10"
            elif 'Op. 25' in piece_part:
                return "Chopin's Études Op. 25"
            else:
                return 'Études (General)'
        elif 'Waltz' in piece_part:
            return "Chopin's Waltzes"
        elif 'Sonata' in piece_part:
            return "Ysaÿe's Violin Sonatas"
        elif 'Suite' in piece_part:
            return "Bach's Cello Suites"
        elif 'Ballade' in piece_part:
            return "Chopin's Ballades"
        else:
            # Default to first word
            return piece_part.split(' ')[0]
    return 'Unknown'

# Create a dictionary to map pieces to their types
piece_to_type = {}

# Map column pieces
for col in df.columns[1:]:  # Skip Piece_1 column
    piece_to_type[col] = get_piece_type(col)

# Map row pieces
for piece in df['Piece_1']:
    piece_to_type[piece] = get_piece_type(piece)

# Get unique piece types
piece_types = sorted(set(piece_to_type.values()))

# Create matrices to store sums and counts
similarity_sum = {t1: {t2: 0 for t2 in piece_types} for t1 in piece_types}
similarity_count = {t1: {t2: 0 for t2 in piece_types} for t1 in piece_types}

# Calculate sums and counts
for _, row in df.iterrows():
    row_piece = row['Piece_1']
    row_type = piece_to_type[row_piece]

    for col_piece in df.columns[1:]:
        col_type = piece_to_type[col_piece]
        similarity = row[col_piece]

        if pd.notna(similarity):
            similarity_sum[row_type][col_type] += similarity
            similarity_count[row_type][col_type] += 1

# Calculate averages
avg_similarity = {t1: {t2: (similarity_sum[t1][t2] / similarity_count[t1][t2]
                           if similarity_count[t1][t2] > 0 else 0)
                      for t2 in piece_types}
                 for t1 in piece_types}

# Convert to pandas DataFrame for easier visualization
avg_df = pd.DataFrame(avg_similarity)

# Create the heatmap with larger figure size for better readability
plt.figure(figsize=(14, 12))

# Increase font sizes throughout matplotlib
plt.rcParams.update({'font.size': 14})

ax = sns.heatmap(
    avg_df,
    annot=True,
    cmap="Blues",
    fmt=".3f",
    linewidths=0.5,
    cbar_kws={"shrink": 0.8},
    annot_kws={"size": 16}  # Larger annotation font size
)

# Adjust axis labels font size
plt.xticks(fontsize=16, rotation=45, ha='right')
plt.yticks(fontsize=16, rotation=45, ha='right')

# Make colorbar ticks larger
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=14)

plt.tight_layout()
plt.savefig('piece_type_similarity.png', dpi=300, bbox_inches='tight')
plt.show()

# Print the average similarity matrix for reference
print("Average Similarity Matrix:")
print(avg_df.round(3))

# Find and print some key insights
print("\nKey Insights:")
print(f"Bach's Cello Suites internal similarity: {avg_df.loc['Bach\'s Cello Suites', 'Bach\'s Cello Suites']:.3f}")
print(f"Chopin's Waltzes and Études Op. 10 similarity: {avg_df.loc['Chopin\'s Waltzes', 'Chopin\'s Études Op. 10']:.3f}")
print(f"Bach's Cello Suites and Ysaÿe's Violin Sonatas similarity: {avg_df.loc['Bach\'s Cello Suites', 'Ysaÿe\'s Violin Sonatas']:.3f}")
print(f"Chopin's Études Op. 10 and Op. 25 similarity: {avg_df.loc['Chopin\'s Études Op. 10', 'Chopin\'s Études Op. 25']:.3f}")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure aesthetics
plt.figure(figsize=(14, 12))

# Load the CSV data
df = pd.read_csv('Output/sim_mat.csv')

# Convert the data to a square matrix format and remove the index name
similarity_matrix = df.set_index('Piece_1')
similarity_matrix.index.name = None  # Remove the "Piece_1" label

# Group pieces by piece type
def get_piece_type(piece_name):
    parts = piece_name.split('|')
    if len(parts) > 1:
        piece_part = parts[1].strip()

        # Special handling for Chopin's Études
        if 'Étude' in piece_part:
            if 'Op. 10' in piece_part:
                return "Chopin's Études Op. 10"
            elif 'Op. 25' in piece_part:
                return "Chopin's Études Op. 25"
            else:
                return "Études (General)"
        elif 'Waltz' in piece_part:
            return "Chopin's Waltzes"
        elif 'Sonata' in piece_part:
            return "Ysaÿe's Violin Sonatas"
        elif 'Suite' in piece_part:
            return "Bach's Cello Suites"
        elif 'Ballade' in piece_part:
            return "Chopin's Ballades"
        else:
            # Default to first word
            return piece_part.split(' ')[0]
    return 'Unknown'


# Sort the matrix by piece type
piece_types = [get_piece_type(piece) for piece in similarity_matrix.index]
sorted_indices = sorted(range(len(piece_types)), key=lambda i: (piece_types[i], similarity_matrix.index[i]))
sorted_pieces = [similarity_matrix.index[i] for i in sorted_indices]

# Reindex the matrix with the sorted pieces
similarity_matrix = similarity_matrix.reindex(index=sorted_pieces, columns=sorted_pieces)

# Create the heatmap
plt.figure(figsize=(16, 14))
ax = sns.heatmap(
    similarity_matrix,
    cmap="Blues",
    annot=False,
    fmt=".2f",
    linewidths=0.5,
    cbar_kws={
        "shrink": 0.8,
        "label": "Similarity Score",
    }
)

# Remove title and axis labels
plt.xticks([])
plt.yticks([])
plt.title("")

# Add divider lines between piece types
prev_type = None
for i, piece in enumerate(similarity_matrix.index):
    current_type = get_piece_type(piece)
    if current_type != prev_type and i > 0:
        plt.axhline(y=i, color='red', linewidth=2)
        plt.axvline(x=i, color='red', linewidth=2)
    prev_type = current_type


plt.tight_layout()
plt.savefig('piece_type_similarity_heatmap.png', dpi=300, bbox_inches='tight')
